# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
import os
import time
import unidecode

# %%
def get_roster_url(team):
    team_new = team.lower().replace(' ', '-')
    roster_url = 'https://www.fangraphs.com/roster-resource/depth-charts/' + team_new
    return roster_url

# %%
# Scrape active roster

def get_roster_source(roster_url,driver):

#    chromedriver = "/usr/local/bin/chromedriver"
#    os.environ["webdriver.chrome.driver"] = chromedriver
    #driver = webdriver.Firefox(executable_path = geckodriver)
    driver.set_page_load_timeout(5)
    try :
        driver.get(roster_url)
    except TimeoutException as e:
        # try again
        driver.get(roster_url)
    time.sleep(5)
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')
    table = soup.find("div", {"class":"depth-chart-wrapper is-spring-training"})
    
    #driver.quit()
    return table

# %%
def get_player_url(roster_table):
    player = []
    player_url = []
    
    dcrt = roster_table.find_all('div',{"class":"depth-charts__roster-tables"})
    
    # first seven tables are the 40 man roster
    for i in range(7):        
        for row2 in dcrt[i].tbody.find_all('td',{"data-stat":"PLAYER"}):
                    
            #player list
            player_tmp = row2.text
            player.append(player_tmp)
                    
            #player url list
            player_url_tmp = row2.find('a')['href']
            size = len(player_url_tmp)
            player_url_tmp = 'https:' + player_url_tmp[:size - 5]
            player_url.append(player_url_tmp)
                    
    return player, player_url

# %%
# Static function for stat_cat == 'advanced' and 'batted-ball'

def batting(url, season, driver):

    #driver = webdriver.Firefox(executable_path = geckodriver)    
    
    batting_url = url + 'splits?season=' + str(season)
    
    driver.set_page_load_timeout(5)
    try :
        driver.get(batting_url)
    except TimeoutException as e:
        try :
            driver.get(batting_url)
        except TimeoutException as e:
            # try again
            driver.get(batting_url)
     
    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')
    
    #In case of rediction to pitch 
    if 'position=P' in driver.current_url:
        real_batting_url = soup.find("div", {"id":"portal-player-pages-menu"}).find("ul",
                        {"class":"menu-player-page__batpitch"}).find_all("a")[0]['href']
        real_batting_url = 'https://www.fangraphs.com/' + real_batting_url + '&season=' + str(season)
        driver.get(real_batting_url)
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')
    table_advanced = soup.find("div", {"id":'advanced',"class":"player-page-table"})
    table_battedball = soup.find("div", {"id":'batted-ball',"class":"player-page-table"})
    
    if (table_advanced is None) or (table_battedball is None):
        print(url,'table_advanced is None')
        # If encountering error page, use Derek Lowe as a dummy pitcher 
        dummy_batting_url = 'https://www.fangraphs.com/players/derek-lowe/199/splits?position=PB&season=' + str(season) 
        driver.get(dummy_batting_url)
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')    
        table_advanced = soup.find("div", {"id":'advanced',"class":"player-page-table"})
        table_battedball = soup.find("div", {"id":'batted-ball',"class":"player-page-table"})
        
    #driver.quit()
    return table_advanced, table_battedball

# %%
# Static function for stat_cat == 'advanced' and 'batted-ball'
def pitching(url, season, driver):

    #driver = webdriver.Firefox(executable_path = geckodriver)    
    
    #Set position=P
    pitching_url = url + 'splits?position=P&season=' + str(season)
    
    driver.set_page_load_timeout(4)
    try :
        driver.get(pitching_url)
    except TimeoutException as e:
        try :
            driver.get(pitching_url)
        except TimeoutException as e:
            # try again
            driver.get(pitching_url)

    source = driver.page_source
    soup = BeautifulSoup(source, 'html.parser')
    table_advanced = soup.find("div", {"id":'advanced',"class":"player-page-table"})
    table_battedball = soup.find("div", {"id":'batted-ball',"class":"player-page-table"})
    if (table_advanced is None) or (table_battedball is None):
        print(pitching_url,'table is None')
    # If encountering error page, use Derek Lowe as a dummy pitcher 
        dummy_url = 'https://www.fangraphs.com/players/derek-lowe/199/splits?position=PB&season=' + str(season) 
        driver.get(dummy_url)
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')    
        table_advanced = soup.find("div", {"id":'advanced',"class":"player-page-table"})
        table_battedball = soup.find("div", {"id":'batted-ball',"class":"player-page-table"})
    
    #driver.quit()
    return table_advanced, table_battedball

# %%
# append new info to df

def advanced_batter_table(table, stat_cat, stat, df, team, player, bat_pitch):
    
    for row in table.tbody.find_all('tr'): 
    # Find all data for each column
        if (row.find_all('th') != []):
    # Replace "Handedness" with function input
            stat_row = row.find_all('th')[1].text
            #print(stat_row)
        if all(stat_row != x for x in stat):
            #if all(row.find_all('th')[1].text != x for x in stat):
            #if (row.find_all('th')[1].text != stat):
            continue
        columns = row.find_all('td')
        if (columns == []):
            continue
        #bat_pitch = Bat_Pitch
        season = columns[0].text.strip()
        split = columns[1].text.strip()
        bb = columns[2].text.strip()
        k_per = columns[3].text.strip()
        bb_k = columns[4].text.strip()
        avg = columns[5].text.strip()
        obp = columns[6].text.strip()
        slg = columns[7].text.strip()
        ops = columns[8].text.strip()
        iso = columns[9].text.strip()
        babip = columns[10].text.strip()
        wrc = columns[11].text.strip()
        wraa = columns[12].text.strip()
        woba = columns[13].text.strip()
        wrc_plus = columns[14].text.strip()
        df = df.append({'Team': team, 'Player': player, 'Bat/Pitch':bat_pitch, 'Stat_cat': stat_cat,'Stat': stat_row, 'Season':season, 'Split':split, 'BB%':bb, 'K%':k_per, 'BB/K':bb_k ,'AVG':avg, 
                    'OBP':obp, 'SLG':slg, 'OPS':ops, 'ISO':iso, 'BABIP':babip, 'wRC':wrc, 
                    'wRAA':wraa, 'wOBA':woba, 'wRC+':wrc_plus}, ignore_index=True)
    return df

# %%
# Static function for stat_cat == 'advanced' and 'batted-ball'

def fg_scrape(team, season, bat_pitch, stat = ['Handedness', 'Home / Away', 'Monthly']):
    start_time = time.time()
    geckodriver = "C:\Program Files (x86)\geckodriver"
    os.environ["webdriver.gecko.driver"] = geckodriver
    driver = webdriver.Firefox(executable_path = geckodriver)
    
    roster_url = get_roster_url(team)
    
    #timeout1 = time.time() + 5
    #while time.time() < timeout1:
    roster_table = get_roster_source(roster_url, driver)
    
    # Full team name
    team_tmp = roster_table.find('h2',{"class":"rr-header undefined"}).text
    team_tmp = team_tmp[:len(team_tmp) - 6]
    
    player, player_url = get_player_url(roster_table)
    
    # URL time
    print("--- getting url takes %s seconds ---" % (time.time() - start_time))

    if (bat_pitch == 'bat'):    
        
        # Generate empty df
        df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat', 'Bat/Pitch','Stat', 'Season', 
                           'Split', 'BB%', 'K%', 'BB/K' ,'AVG', 'OBP', 
                           'SLG', 'OPS', 'ISO', 'BABIP', 'wRC', 'wRAA', 'wOBA', 'wRC+'])
        df_battedball = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes'])         
        # Loop over players
        for i in range(len(player_url)):
                #table = batting(player_url[i], season, stat_cat, driver)
            print(player[i])
            
            table_advanced, table_battedball = batting(player_url[i], season, driver)
            
            print("--- scraping tables takes %s seconds ---" % (time.time() - start_time))
            
            df_advanced = advanced_batter_table(table_advanced, 'advanced', stat, df_advanced, team = team_tmp, player = player[i], bat_pitch = 'Batter')
            print("--- formatting first table takes %s seconds ---" % (time.time() - start_time))
            
            df_battedball = battedball_table(table_battedball, 'batted-ball', stat, df_battedball, team = team_tmp, player = player[i], bat_pitch = 'Batter')   
            print("--- formatting second table takes %s seconds ---" % (time.time() - start_time))
        
        df_advanced.to_csv(team + '_' + str(season) + "_bat_advanced.csv", index = False)
        df_battedball.to_csv(team + '_' + str(season) + "_bat_battedball.csv", index = False)
        
        #return df_advanced, df_battedball
   

    if (bat_pitch == 'pitch'):
        df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'K/9', 'BB/9', 'K/BB','HR/9','K%','BB%','K-BB%','AVG',
                           'WHIP','BABIP','LOB%','FIP','xFIP'])
        df_battedball = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes'])        
        
        for i in range(len(player_url)):
            print(player[i])

            table_advanced, table_battedball = pitching(player_url[i], season, driver)
            df_advanced = advanced_pitcher_table(table_advanced, 'advanced', stat, df_advanced, team = team_tmp, player = player[i], bat_pitch = 'Pitcher')
            df_battedball = battedball_table(table_battedball, 'batted-ball', stat, df_battedball, team = team_tmp, player = player[i], bat_pitch = 'Pitcher')
            print("--- formatting second table takes %s seconds ---" % (time.time() - start_time))
        df_advanced.to_csv(team + '_' + str(season) + "_pitch_advanced.csv" ,index = False)
        df_battedball.to_csv(team + '_' + str(season) + "_pitch_battedball.csv",index = False)
        
    driver.quit()
    print("--- %s seconds ---" % (time.time() - start_time))
        #return df_advanced, df_battedball

# %%
# append new info to df

def advanced_pitcher_table(table, stat_cat, stat, df, team, player, bat_pitch):
    
    for row in table.tbody.find_all('tr'): 
    # Find all data for each column
        if (row.find_all('th') != []):
    # Replace "Handedness" with function input
            stat_row = row.find_all('th')[1].text
            #print(stat_row)
        if all(stat_row != x for x in stat):
            #if all(row.find_all('th')[1].text != x for x in stat):
            #if (row.find_all('th')[1].text != stat):
            continue
        columns = row.find_all('td')
        if (columns == []):
            continue
        #bat_pitch = Bat_Pitch
        season = columns[0].text.strip()
        split = columns[1].text.strip()  
        k_9 = columns[2].text.strip()
        bb_9 = columns[3].text.strip()
        k_bb = columns[4].text.strip()
        hr_9 = columns[5].text.strip()
        k = columns[6].text.strip()
        bb = columns[7].text.strip()
        kbb = columns[8].text.strip()
        avg = columns[9].text.strip()
        whip = columns[10].text.strip()
        babip = columns[11].text.strip()
        lob = columns[12].text.strip()
        fip = columns[13].text.strip()
        xfip = columns[14].text.strip()
        
        df = df.append({'Team': team, 'Player': player, 'Bat/Pitch':bat_pitch, 'Stat_cat': stat_cat,'Stat': stat_row, 'Season':season, 'Split':split, 
                        'K/9':k_9, 'BB/9':bb_9, 'K/BB':k_bb,'HR/9':hr_9,'K%':k,'BB%':bb,'K-BB%':kbb,'AVG':avg,
                           'WHIP':whip,'BABIP':babip,'LOB%':lob,'FIP':fip,'xFIP':xfip}, ignore_index=True)
    return df

# %%
roster_url = get_roster_url('rockies')

# %%
roster_table = get_roster_source(roster_url,driver)

# %%
roster_table.find('h2',{"class":"rr-header undefined"}).text
# Out:
# 'COLORADO ROCKIES 2022▼'

# %%
player, player_url = get_player_url(roster_table)

# %%
batting_table = batting('https://www.fangraphs.com/players/john-schreiber/20020/', 2022, driver)

# %%
# static test
table_advanced, table_battedball = batting('https://www.fangraphs.com/players/john-schreiber/20020/', 2022, driver)

batting_table = batting('https://www.fangraphs.com/players/antonio-senzatela/15488/', 2022, stat_cat = 'advanced',driver)

# %%
table_advanced, table_battedball = pitching('https://www.fangraphs.com/players/scott-oberg/13911/', 2022, driver)

# %%
table_battedball
# Out:
# <div class="player-page-table" id="batted-ball"><div class="player-page-table__header"><a href="#Batted Ball" id="Batted Ball"><h2>Batted Ball</h2></a></div><div><div class="fg-data-grid undefined sort-disabled"><div class="table-wrapper-outer"><div class="table-wrapper-inner"><div class="table-scroll"><table><tbody></tbody></table></div><div class="table-fixed"><table><tbody></tbody></table></div></div></div></div></div></div>

# %%
table_advanced
# Out:
# <div class="player-page-table" id="advanced"><div class="player-page-table__header"><a href="#Advanced" id="Advanced"><h2>Advanced</h2></a></div><div><div class="fg-data-grid undefined sort-disabled"><div class="table-wrapper-outer"><div class="table-wrapper-inner"><div class="table-scroll"><table><tbody><tr class=""><th class="align-left fixed undefined" data-col="0" data-stat="Season">Season</th><th class="align-left fixed undefined" data-col="1" data-stat="Split">Handedness</th><th class="align-right undefined" data-col="2" data-stat="K/9">K/9</th><th class="align-right undefined" data-col="3" data-stat="BB/9">BB/9</th><th class="align-right undefined" data-col="4" data-stat="K/BB">K/BB</th><th class="align-right undefined" data-col="5" data-stat="HR/9">HR/9</th><th class="align-right undefined" data-col="6" data-stat="K%">K%</th><th class="align-right undefined" data-col="7" data-stat="BB%">BB%</th><th class="align-right undefined" data-

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16604/2044282367.py in <module>
# ----> 1 advanced_pitcher_table(table_battedball, 'batted-ball', ['Handedness', 'Home / Away',  'Monthly'], df, 'red sox',
#       2                        'antonio-senzatela', 'pitch')
#
# NameError: name 'advanced_pitcher_table' is not defined

# %%
df = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'BB%', 'K%', 'BB/K' ,'AVG', 'OBP', 
                           'SLG', 'OPS', 'ISO', 'BABIP', 'wRC', 'wRAA', 'wOBA', 'wRC+'])

# %%
stat = ['Handedness', 'Home / Away',  'Monthly']

advanced_batter_table(batting_table, 'advanced', stat, df, team = 'red sox', player = 'batman' , bat_pitch ='Batter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/4214318982.py in <module>
#       1 stat = ['Handedness', 'Home / Away',  'Monthly']
#       2
# ----> 3 advanced_batter_table(batting_table, 'advanced', stat, df, team = 'red sox', player = 'batman' , bat_pitch ='Batter')
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'K/9', 'BB/9', 'K/BB','HR/9','K%','BB%','K-BB%','AVG',
                           'WHIP','BABIP','LOB%','FIP','xFIP'])

# %%
# test
advanced_pitcher_table(pitching_table, 'advanced', stat, df, team = 'red sox', player = 'batman' , bat_pitch ='pitcher')
# Out:
#       Team  Player  Stat_cat Bat/Pitch         Stat Season      Split   K/9  \
# 0  red sox  batman  advanced   pitcher   Handedness   2022       vs L  0.00
# 1  red sox  batman  advanced   pitcher   Handedness   2022       vs R  0.00
# 2  red sox  batman  advanced   pitcher  Home / Away   2022       Away  0.00
# 3  red sox  batman  advanced   pitcher  Home / Away   2022  Away vs L  0.00
# 4  red sox  batman  advanced   pitcher  Home / Away   2022  Away vs R  0.00
# 5  red sox  batman  advanced   pitcher      Monthly   2022        May  0.00
# 6  red sox  batman  advanced   pitcher      Monthly   2022   1st Half  0.00
#
#    BB/9  K/BB  HR/9    K%   BB% K-BB%   AVG  WHIP BABIP    LOB%   FIP  xFIP
# 0  0.00  0.00  0.00  0.0%  0.0%  0.0%  .000  0.00  .000  100.0%  3.14  7.43
# 1  0.00  0.00  0.00  0.0%  0.0%  0.0%  .333  1.50  .333  100.0%  3.14  7.43
# 2  0.00  0.00  0.00  0.0%  0.0%  0.0%  .250  1.00  .250  100.0%  3.14  7.43
# 3  0.00  0.00  0.00  0.0%  0.0%  0.0%  .000  0.00  .000  100.0%  3.14  7.43
# 4  0.00  0.00  0.00  0.0%  0.0%  0.0%  .333  1.50  .333  100.0%  3.14  7.43
# 5  0.00  0.00  0.00  0.0%  0.0%  0.0%  .250  1.00  .250  100.0%  3.14  7.43
# 6  0.00  0.00  0.00  0.0%  0.0%  0.0%  .250  1.00  .250  100.0%  3.14  7.43

# %%
df = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes'])

# %%
stat = ['Handedness', 'Home / Away', 'Monthly']

battedball_table(batting_table, 'advanced', stat, df, team = 'red sox', player = 'batman' , bat_pitch ='Batter')
# Out:
#        Team  Player  Stat_cat Bat/Pitch         Stat Season      Split  K/9  \
# 0   red sox  batman  advanced    Batter   Handedness   2022  vs L as R  NaN
# 1   red sox  batman  advanced    Batter   Handedness   2022  vs R as R  NaN
# 2   red sox  batman  advanced    Batter   Handedness   2022       vs L  NaN
# 3   red sox  batman  advanced    Batter   Handedness   2022       vs R  NaN
# 4   red sox  batman  advanced    Batter  Home / Away   2022       Home  NaN
# 5   red sox  batman  advanced    Batter  Home / Away   2022       Away  NaN
# 6   red sox  batman  advanced    Batter  Home / Away   2022  Home vs L  NaN
# 7   red sox  batman  advanced    Batter  Home / Away   2022  Home vs R  NaN
# 8   red sox  batman  advanced    Batter  Home / Away   2022  Away vs L  NaN
# 9   red sox  batman  advanced    Batter  Home / Away   2022  Away vs R  NaN
# 10  red sox  batman  advanced    Batter      Monthly   2022    Mar/Apr  NaN
# 11  red sox  batman  advanced    Batter      Monthly   2022        May  NaN
# 12  red sox  batman  advanced    Batter      Monthly   2022        Jun  NaN
# 13  red sox  batman  advanced    Batter      Monthly   2022   1st Half  NaN
#
#    BB/9 K/BB  ...  Hard%  IFFB%  IFH%    LD%   Med%  Oppo% Pitches  Pull%  \
# 0   NaN  NaN  ...  23.8%  15.0%  0.0%  14.3%  57.1%  21.4%     207  47.6%
# 1   NaN  NaN  ...  28.3%  25.7%  6.5%  15.9%  44.2%  23.2%     616  43.5%
# 2   NaN  NaN  ...  23.8%  15.0%  0.0%  14.3%  57.1%  21.4%     207  47.6%
# 3   NaN  NaN  ...  28.3%  25.7%  6.5%  15.9%  44.2%  23.2%     616  43.5%
# 4   NaN  NaN  ...  19.5%  30.2%  6.3%  13.8%  50.6%  31.0%     328  39.1%
# 5   NaN  NaN  ...  34.4%  17.0%  3.3%  17.2%  44.1%  15.1%     495  49.5%
# 6   NaN  NaN  ...  13.3%  14.3%  0.0%  26.7%  60.0%  26.7%      63  33.3%
# 7   NaN  NaN  ...  20.8%  33.3%  7.1%  11.1%  48.6%  31.9%     265  40.3%
# 8   NaN  NaN  ...  29.6%  15.4%  0.0%   7.4%  55.6%  18.5%     144  55.6%
# 9   NaN  NaN  ...  36.4%  17.6%  5.6%  21.2%  39.4%  13.6%     351  47.0%
# 10  NaN  NaN  ...  31.3%  33.3%  5.0%  17.2%  42.2%  23.4%     348  50.0%
# 11  NaN  NaN  ...  24.5%  19.2%  5.4%  12.7%  48.0%  24.5%     406  42.2%
# 12  NaN  NaN  ...  28.6%   0.0%  0.0%  28.6%  64.3%   7.1%      69  35.7%
# 13  NaN  NaN  ...  27.2%  23.3%  4.8%  15.6%  47.2%  22.8%     823  44.4%
#
#     Soft% Strikes
# 0   19.0%     130
# 1   27.5%     387
# 2   19.0%     130
# 3   27.5%     387
# 4   29.9%     206
# 5   21.5%     311
# 6   26.7%      37
# 7   30.6%     169
# 8   14.8%      93
# 9   24.2%     218
# 10  26.6%     216
# 11  27.5%     258
# 12   7.1%      43
# 13  25.6%     517
#
# [14 rows x 37 columns]

# %%
start_time = time.time()
df = fg_scrape(team = 'red sox', season = 2021, bat_pitch = 'bat', stat_cat ='advanced', stat = ['Handedness', 'Home / Away', 'Monthly'])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/1890142216.py in <module>
#       1 start_time = time.time()
# ----> 2 df = fg_scrape(team = 'red sox', season = 2021, bat_pitch = 'bat', stat_cat ='advanced', stat = ['Handedness', 'Home / Away', 'Monthly'])
#       3 print("--- %s seconds ---" % (time.time() - start_time))
#       4
#
# ~\AppData\Local\Temp/ipykernel_4528/2590323622.py in fg_scrape(team, season, bat_pitch, stat_cat, stat)
#      29         for i in range(len(player_url)):
#      30                 #table = batting(player_url[i], season, stat_cat, driver)
# ---> 31             table_advanced, table_battedball = batting(player_url[i], season, driver)
#      32             df_advanced = advanced_batter_table(table_advanced, 'advanced', stat, df_advanced, team = team_tmp, player = player[i], bat_pitch = 'Batter')
#      33             df_battedball = battedball_table(table_battedball, 'batted-ball', stat, df_battedball, team = team_tmp, player = player[i], bat_pitch = 'Batter')
#
# ~\AppData\Local\Temp/ipykernel_4528/3438555492.py in batting(url, season, driver)
#       7     batting_url = url + 'splits?season=' + str(season)
#       8
# ----> 9     driver.get(batting_url)
#      10     source = driver.page_source
#      11     soup = BeautifulSoup(source, 'html.parser')
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# T:\Anaconda\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# T:\Anaconda\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# T:\Anaconda\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# T:\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# T:\Anaconda\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# T:\Anaconda\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# T:\Anaconda\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# T:\Anaconda\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df.to_csv("2021_BOS_bat_batted-ball.csv",index = False)

# %%
df
# Out:
#                Team            Player  Stat_cat Bat/Pitch         Stat Season  \
# 0    BOSTON RED SOX   Franchy Cordero  advanced    Batter   Handedness   2021
# 1    BOSTON RED SOX   Franchy Cordero  advanced    Batter   Handedness   2021
# 2    BOSTON RED SOX   Franchy Cordero  advanced    Batter   Handedness   2021
# 3    BOSTON RED SOX   Franchy Cordero  advanced    Batter   Handedness   2021
# 4    BOSTON RED SOX   Franchy Cordero  advanced    Batter  Home / Away   2021
# ..              ...               ...       ...       ...          ...    ...
# 207  BOSTON RED SOX  Christian Arroyo  advanced    Batter      Monthly   2021
# 208  BOSTON RED SOX  Christian Arroyo  advanced    Batter      Monthly   2021
# 209  BOSTON RED SOX  Christian Arroyo  advanced    Batter      Monthly   2021
# 210  BOSTON RED SOX  Christian Arroyo  advanced    Batter      Monthly   2021
# 211  BOSTON RED SOX  Christian Arroyo  advanced    Batter      Monthly   2021
#
#          Split    BB%     K%  BB/K   AVG   OBP   SLG   OPS   ISO BABIP wRC  \
# 0    vs L as L   5.6%  33.3%  0.17  .188  .235  .188  .423  .000  .300   0
# 1    vs R as L   5.9%  38.1%  0.16  .189  .237  .270  .508  .081  .308   6
# 2         vs L   5.6%  33.3%  0.17  .188  .235  .188  .423  .000  .300   0
# 3         vs R   5.9%  38.1%  0.16  .189  .237  .270  .508  .081  .308   6
# 4         Home   5.7%  42.9%  0.13  .227  .271  .303  .574  .076  .417   5
# ..         ...    ...    ...   ...   ...   ...   ...   ...   ...   ...  ..
# 207        Jul   6.3%   9.4%  0.67  .300  .344  .600  .944  .300  .280   6
# 208        Aug   0.0%   0.0%  0.00  .000  .200  .000  .200  .000  .000   0
# 209   Sept/Oct  16.7%  50.0%  0.33  .200  .333  .200  .533  .000  .500   0
# 210   1st Half   4.3%  24.5%  0.18  .264  .323  .439  .762  .176  .330  22
# 211   2nd Half   5.6%  22.2%  0.25  .250  .333  .500  .833  .250  .273   3
#
#      wRAA  wOBA wRC+
# 0    -1.8  .196   14
# 1    -8.7  .225   34
# 2    -1.8  .196   14
# 3    -8.7  .225   34
# 4    -3.5  .254   49
# ..    ...   ...  ...
# 207   2.1  .395  149
# 208  -0.7  .144  -21
# 209  -0.3  .262   59
# 210   2.1  .330  105
# 211   0.6  .357  123
#
# [212 rows x 20 columns]

# %%
df_advanced, df_battedball = fg_scrape(team = 'red sox', season = 2022, bat_pitch = 'bat', stat = ['Handedness', 'Home / Away', 'Monthly'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/414370532.py in <module>
# ----> 1 df_advanced, df_battedball = fg_scrape(team = 'red sox', season = 2022, bat_pitch = 'bat', stat = ['Handedness', 'Home / Away', 'Monthly'])
#
# ~\AppData\Local\Temp/ipykernel_4528/1122465627.py in fg_scrape(team, season, bat_pitch, stat)
#       9     roster_url = get_roster_url(team)
#      10
# ---> 11     roster_table = get_roster_source(roster_url, driver)
#      12     # Full team name
#      13     team_tmp = roster_table.find('h2',{"class":"rr-header undefined"}).text
#
# ~\AppData\Local\Temp/ipykernel_4528/1765811770.py in get_roster_source(roster_url, driver)
#       6 #    os.environ["webdriver.chrome.driver"] = chromedriver
#       7     #driver = webdriver.Firefox(executable_path = geckodriver)
# ----> 8     driver.get(roster_url)
#       9     time.sleep(10)
#      10     source = driver.page_source
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# T:\Anaconda\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# T:\Anaconda\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# T:\Anaconda\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# T:\Anaconda\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# T:\Anaconda\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# T:\Anaconda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# T:\Anaconda\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# T:\Anaconda\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# T:\Anaconda\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# T:\Anaconda\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# time test - why bat takes so long
fg_scrape('red sox', 2022, 'bat', stat = ['Handedness', 'Home / Away', 'Monthly'])

# %%
os.chdir('T:\\Baseball\\export\\6_15_export')

# %%
# Group test

os.chdir('T:\\Baseball\\export\\7_13_export')

#teams = ['orioles','red sox','white sox', 'guardians', 'tigers', 'astros', 'royals', 'angels', 'twins', 'yankees',
#            'athletics', 'mariners' , 'rays', 'rangers', 'blue jays', 'diamondbacks', 'braves','cubs','reds',
#             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
#             'nationals']

teams = [
             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
             'nationals']

#teams = ['marlins']

#seasons = ['2021','2022']
seasons = ['2022']
#stat = ['Handedness', 'Home / Away', 'Monthly']
stat = ['Handedness']

for team in teams:
    for season in seasons:
        fg_scrape(team, season, 'bat', stat)
        fg_scrape(team, season, 'pitch', stat)
# Out:
# --- getting url takes 15.183220148086548 seconds ---
# Connor Joe
# --- scraping tables takes 16.943760633468628 seconds ---
# --- formatting first table takes 16.960716485977173 seconds ---
# --- formatting second table takes 16.975674867630005 seconds ---
# José Iglesias
# --- scraping tables takes 19.315414905548096 seconds ---
# --- formatting first table takes 19.326383590698242 seconds ---
# --- formatting second table takes 19.3373544216156 seconds ---
# Charlie Blackmon
# --- scraping tables takes 22.17875051498413 seconds ---
# --- formatting first table takes 22.189745664596558 seconds ---
# --- formatting second table takes 22.20168948173523 seconds ---
# C.J. Cron
# --- scraping tables takes 24.18139100074768 seconds ---
# --- formatting first table takes 24.19236183166504 seconds ---
# --- formatting second table takes 24.206324100494385 seconds ---
# Brendan Rodgers
# --- scraping tables takes 26.198992490768433 seconds ---
# --- formatting first table takes 26.210960149765015 seconds ---
# --- formatting second table takes 26.227914810180664 seconds ---
# Ryan McMahon
# --- scraping tables takes 28.546708583831787 seconds ---
# --- formatting first table takes 28.556682586669922 seconds ---
# --- formatting second table takes 28.569647789001465 seconds ---
# Randal Grichuk
# --- scraping tables takes 30.618166208267212 seconds ---
# --- formatting first table takes 30.629136562347412 seconds ---
# --- formatting second table takes 30.64013123512268 seconds ---
# Sam Hilliard
# --- scraping tables takes 32.75245475769043 seconds ---
# --- formatting first table takes 32.76442265510559 seconds ---
# --- formatting second table takes 32.782374143600464 seconds ---
# Elias Díaz
# --- scraping tables takes 34.717196226119995 seconds ---
# --- formatting first table takes 34.72816729545593 seconds ---
# --- formatting second table takes 34.740134954452515 seconds ---
# Brian Serven
# --- scraping tables takes 37.16364932060242 seconds ---
# --- formatting first table takes 37.174620389938354 seconds ---
# --- formatting second table takes 37.185590744018555 seconds ---
# Elehuris Montero
# --- scraping tables takes 39.022674798965454 seconds ---
# --- formatting first table takes 39.032674074172974 seconds ---
# --- formatting second table takes 39.04661154747009 seconds ---
# Garrett Hampson
# --- scraping tables takes 41.253705739974976 seconds ---
# --- formatting first table takes 41.2666699886322 seconds ---
# --- formatting second table takes 41.27764010429382 seconds ---
# Yonathan Daza
# --- scraping tables takes 43.105748653411865 seconds ---
# --- formatting first table takes 43.11871409416199 seconds ---
# --- formatting second table takes 43.13367319107056 seconds ---
# Germán Márquez
# https://www.fangraphs.com/players/german-marquez/15038/ table_advanced is None
# --- scraping tables takes 47.20278453826904 seconds ---
# --- formatting first table takes 47.20278453826904 seconds ---
# --- formatting second table takes 47.20278453826904 seconds ---
# José Ureña
# https://www.fangraphs.com/players/jose-urena/11589/ table_advanced is None
# --- scraping tables takes 51.549152851104736 seconds ---
# --- formatting first table takes 51.549152851104736 seconds ---
# --- formatting second table takes 51.549152851104736 seconds ---
# Austin Gomber
# https://www.fangraphs.com/players/austin-gomber/16561/ table_advanced is None
# --- scraping tables takes 55.54446721076965 seconds ---
# --- formatting first table takes 55.54446721076965 seconds ---
# --- formatting second table takes 55.54546403884888 seconds ---
# Chad Kuhl
# https://www.fangraphs.com/players/chad-kuhl/14975/ table_advanced is None
# --- scraping tables takes 59.84495306015015 seconds ---
# --- formatting first table takes 59.84595036506653 seconds ---
# --- formatting second table takes 59.84595036506653 seconds ---
# Kyle Freeland
# https://www.fangraphs.com/players/kyle-freeland/16256/ table_advanced is None
# --- scraping tables takes 64.34940767288208 seconds ---
# --- formatting first table takes 64.35040616989136 seconds ---
# --- formatting second table takes 64.35140085220337 seconds ---
# Daniel Bard
# https://www.fangraphs.com/players/daniel-bard/7115/ table_advanced is None
# --- scraping tables takes 69.24000430107117 seconds ---
# --- formatting first table takes 69.24000430107117 seconds ---
# --- formatting second table takes 69.24000430107117 seconds ---
# Alex Colomé
# https://www.fangraphs.com/players/alex-colome/6661/ table_advanced is None
# --- scraping tables takes 73.8966133594513 seconds ---
# --- formatting first table takes 73.8966133594513 seconds ---
# --- formatting second table takes 73.89761304855347 seconds ---
# Carlos Estévez
# https://www.fangraphs.com/players/carlos-estevez/14542/ table_advanced is None
# --- scraping tables takes 78.17702007293701 seconds ---
# --- formatting first table takes 78.17702007293701 seconds ---
# --- formatting second table takes 78.17702007293701 seconds ---
# Lucas Gilbreath
# https://www.fangraphs.com/players/lucas-gilbreath/21290/ table_advanced is None
# --- scraping tables takes 82.30397629737854 seconds ---
# --- formatting first table takes 82.30397629737854 seconds ---
# --- formatting second table takes 82.30397629737854 seconds ---
# Robert Stephenson
# https://www.fangraphs.com/players/robert-stephenson/13594/ table_advanced is None
# --- scraping tables takes 86.20354056358337 seconds ---
# --- formatting first table takes 86.20354056358337 seconds ---
# --- formatting second table takes 86.20354056358337 seconds ---
# Jake Bird
# https://www.fangraphs.com/players/jake-bird/21267/ table_advanced is None
# --- scraping tables takes 91.08547639846802 seconds ---
# --- formatting first table takes 91.08547639846802 seconds ---
# --- formatting second table takes 91.08547639846802 seconds ---
# Ty Blach
# https://www.fangraphs.com/players/ty-blach/14361/ table_advanced is None
# --- scraping tables takes 97.19316959381104 seconds ---
# --- formatting first table takes 97.19316959381104 seconds ---
# --- formatting second table takes 97.19316959381104 seconds ---
# Jhoulys Chacín
# https://www.fangraphs.com/players/jhoulys-chacin/2608/ table_advanced is None
# --- scraping tables takes 102.07011842727661 seconds ---
# --- formatting first table takes 102.07011842727661 seconds ---
# --- formatting second table takes 102.07011842727661 seconds ---
# Sean Bouchard
# --- scraping tables takes 103.91318678855896 seconds ---
# --- formatting first table takes 103.92515587806702 seconds ---
# --- formatting second table takes 103.94011402130127 seconds ---
# Helcris Olivarez
# https://www.fangraphs.com/players/helcris-olivarez/sa3002965/ table_advanced is None
# --- scraping tables takes 106.66883945465088 seconds ---
# --- formatting first table takes 106.66980957984924 seconds ---
# --- formatting second table takes 106.66980957984924 seconds ---
# Ryan Rolison
# https://www.fangraphs.com/players/ryan-rolison/sa3008244/ table_advanced is None
# --- scraping tables takes 109.95900821685791 seconds ---
# --- formatting first table takes 109.95900821685791 seconds ---
# --- formatting second table takes 109.95900821685791 seconds ---
# Antonio Senzatela
# https://www.fangraphs.com/players/antonio-senzatela/15488/ table_advanced is None
# --- scraping tables takes 114.1288492679596 seconds ---
# --- formatting first table takes 114.1288492679596 seconds ---
# --- formatting second table takes 114.1288492679596 seconds ---
# Tyler Kinley
# https://www.fangraphs.com/players/tyler-kinley/18297/ table_advanced is None
# --- scraping tables takes 119.15044116973877 seconds ---
# --- formatting first table takes 119.15044116973877 seconds ---
# --- formatting second table takes 119.15044116973877 seconds ---
# Scott Oberg
# https://www.fangraphs.com/players/scott-oberg/13911/ table_advanced is None
# --- scraping tables takes 123.84288430213928 seconds ---
# --- formatting first table takes 123.84288430213928 seconds ---
# --- formatting second table takes 123.84288430213928 seconds ---
# --- 126.05795621871948 seconds ---
# --- getting url takes 14.983493089675903 seconds ---
# Connor Joe
# --- formatting second table takes 16.06559681892395 seconds ---
# José Iglesias
# --- formatting second table takes 17.89569902420044 seconds ---
# Charlie Blackmon
# --- formatting second table takes 19.073546409606934 seconds ---
# C.J. Cron
# --- formatting second table takes 20.79610300064087 seconds ---
# Brendan Rodgers
# --- formatting second table takes 22.559062957763672 seconds ---
# Ryan McMahon
# --- formatting second table takes 24.828951835632324 seconds ---
# Randal Grichuk
# --- formatting second table takes 26.162777423858643 seconds ---
# Sam Hilliard
# --- formatting second table takes 27.767191648483276 seconds ---
# Elias Díaz
# --- formatting second table takes 30.005711793899536 seconds ---
# Brian Serven
# --- formatting second table takes 32.26491069793701 seconds ---
# Elehuris Montero
# --- formatting second table takes 34.05756735801697 seconds ---
# Garrett Hampson
# --- formatting second table takes 35.77297806739807 seconds ---
# Yonathan Daza
# --- formatting second table takes 38.22496032714844 seconds ---
# Germán Márquez
# --- formatting second table takes 39.66593909263611 seconds ---
# José Ureña
# --- formatting second table takes 41.07211661338806 seconds ---
# Austin Gomber
# --- formatting second table takes 43.531314849853516 seconds ---
# Chad Kuhl
# --- formatting second table takes 44.953040599823 seconds ---
# Kyle Freeland
# --- formatting second table takes 46.37784266471863 seconds ---
# Daniel Bard
# --- formatting second table takes 48.295727252960205 seconds ---
# Alex Colomé
# --- formatting second table takes 50.64356541633606 seconds ---
# Carlos Estévez
# --- formatting second table takes 52.42869973182678 seconds ---
# Lucas Gilbreath
# --- formatting second table takes 54.071422815322876 seconds ---
# Robert Stephenson
# --- formatting second table takes 55.5439817905426 seconds ---
# Jake Bird
# --- formatting second table takes 57.31430435180664 seconds ---
# Ty Blach
# --- formatting second table takes 59.99318981170654 seconds ---
# Jhoulys Chacín
# --- formatting second table takes 61.89354133605957 seconds ---
# Sean Bouchard
# --- formatting second table takes 64.39659142494202 seconds ---
# Helcris Olivarez
# https://www.fangraphs.com/players/helcris-olivarez/sa3002965/splits?position=P&season=2022 table is None
# --- formatting second table takes 67.87214732170105 seconds ---
# Ryan Rolison
# https://www.fangraphs.com/players/ryan-rolison/sa3008244/splits?position=P&season=2022 table is None
# --- formatting second table takes 71.54254007339478 seconds ---
# Antonio Senzatela
# --- formatting second table takes 73.03974437713623 seconds ---
# Tyler Kinley
# --- formatting second table takes 74.61848855018616 seconds ---
# Scott Oberg
# --- formatting second table takes 75.64848327636719 seconds ---
# --- 78.33158588409424 seconds ---
# --- getting url takes 15.162609577178955 seconds ---
# Mookie Betts
# --- scraping tables takes 18.434142589569092 seconds ---
# --- formatting first table takes 18.444114208221436 seconds ---
# --- formatting second table takes 18.45508313179016 seconds ---
# Trea Turner
# --- scraping tables takes 20.122565984725952 seconds ---
# --- formatting first table takes 20.135531187057495 seconds ---
# --- formatting second table takes 20.155478954315186 seconds ---
# Freddie Freeman
# --- scraping tables takes 22.28296685218811 seconds ---
# --- formatting first table takes 22.29393696784973 seconds ---
# --- formatting second table takes 22.313883304595947 seconds ---
# Will Smith
# --- scraping tables takes 24.03249979019165 seconds ---
# --- formatting first table takes 24.046462297439575 seconds ---
# --- formatting second table takes 24.058429718017578 seconds ---
# Justin Turner
# --- scraping tables takes 26.079708576202393 seconds ---
# --- formatting first table takes 26.089680910110474 seconds ---
# --- formatting second table takes 26.101672887802124 seconds ---
# Cody Bellinger
# --- scraping tables takes 28.13530707359314 seconds ---
# --- formatting first table takes 28.147275686264038 seconds ---
# --- formatting second table takes 28.163231134414673 seconds ---
# Max Muncy
# --- scraping tables takes 30.155073165893555 seconds ---
# --- formatting first table takes 30.16903519630432 seconds ---
# --- formatting second table takes 30.18100380897522 seconds ---
# Jake Lamb
# --- scraping tables takes 31.93722128868103 seconds ---
# --- formatting first table takes 31.944202184677124 seconds ---
# --- formatting second table takes 31.951183557510376 seconds ---
# Gavin Lux
# --- scraping tables takes 33.92484164237976 seconds ---
# --- formatting first table takes 33.937806606292725 seconds ---
# --- formatting second table takes 33.95276713371277 seconds ---
# Austin Barnes
# --- scraping tables takes 35.74099397659302 seconds ---
# --- formatting first table takes 35.755953311920166 seconds ---
# --- formatting second table takes 35.773905754089355 seconds ---
# Hanser Alberto
# --- scraping tables takes 37.78336000442505 seconds ---
# --- formatting first table takes 37.793333530426025 seconds ---
# --- formatting second table takes 37.80530142784119 seconds ---
# Zach McKinstry
# --- scraping tables takes 40.51909303665161 seconds ---
# --- formatting first table takes 40.52607607841492 seconds ---
# --- formatting second table takes 40.533055543899536 seconds ---
# Trayce Thompson
# --- scraping tables takes 42.55486750602722 seconds ---
# --- formatting first table takes 42.56783390045166 seconds ---
# --- formatting second table takes 42.5907723903656 seconds ---
# Clayton Kershaw
# https://www.fangraphs.com/players/clayton-kershaw/2036/ table_advanced is None
# --- scraping tables takes 47.41172456741333 seconds ---
# --- formatting first table takes 47.41172456741333 seconds ---
# --- formatting second table takes 47.41172456741333 seconds ---
# Julio Urías
# https://www.fangraphs.com/players/julio-urias/14765/ table_advanced is None
# --- scraping tables takes 52.393144607543945 seconds ---
# --- formatting first table takes 52.393144607543945 seconds ---
# --- formatting second table takes 52.393144607543945 seconds ---
# Mitch White
# https://www.fangraphs.com/players/mitch-white/19225/ table_advanced is None
# --- scraping tables takes 56.976043939590454 seconds ---
# --- formatting first table takes 56.976043939590454 seconds ---
# --- formatting second table takes 56.976043939590454 seconds ---
# Tony Gonsolin
# https://www.fangraphs.com/players/tony-gonsolin/19388/ table_advanced is None
# --- scraping tables takes 60.68922686576843 seconds ---
# --- formatting first table takes 60.68922686576843 seconds ---
# --- formatting second table takes 60.68922686576843 seconds ---
# Tyler Anderson
# https://www.fangraphs.com/players/tyler-anderson/12880/ table_advanced is None
# --- scraping tables takes 68.05135583877563 seconds ---
# --- formatting first table takes 68.0523521900177 seconds ---
# --- formatting second table takes 68.0523521900177 seconds ---
# Craig Kimbrel
# https://www.fangraphs.com/players/craig-kimbrel/6655/ table_advanced is None
# --- scraping tables takes 72.56397795677185 seconds ---
# --- formatting first table takes 72.56397795677185 seconds ---
# --- formatting second table takes 72.56397795677185 seconds ---
# Brusdar Graterol
# https://www.fangraphs.com/players/brusdar-graterol/20367/ table_advanced is None
# --- scraping tables takes 76.45934772491455 seconds ---
# --- formatting first table takes 76.45934772491455 seconds ---
# --- formatting second table takes 76.45934772491455 seconds ---
# Evan Phillips
# https://www.fangraphs.com/players/evan-phillips/17734/ table_advanced is None
# --- scraping tables takes 82.7909848690033 seconds ---
# --- formatting first table takes 82.7909848690033 seconds ---
# --- formatting second table takes 82.7909848690033 seconds ---
# Alex Vesia
# https://www.fangraphs.com/players/alex-vesia/25007/ table_advanced is None
# --- scraping tables takes 87.48841428756714 seconds ---
# --- formatting first table takes 87.48841428756714 seconds ---
# --- formatting second table takes 87.48841428756714 seconds ---
# Yency Almonte
# https://www.fangraphs.com/players/yency-almonte/15068/ table_advanced is None
# --- scraping tables takes 91.87389945983887 seconds ---
# --- formatting first table takes 91.87389945983887 seconds ---
# --- formatting second table takes 91.87389945983887 seconds ---
# Phil Bickford
# https://www.fangraphs.com/players/phil-bickford/18519/ table_advanced is None
# --- scraping tables takes 96.46983981132507 seconds ---
# --- formatting first table takes 96.46983981132507 seconds ---
# --- formatting second table takes 96.46983981132507 seconds ---
# Caleb Ferguson
# https://www.fangraphs.com/players/caleb-ferguson/19349/ table_advanced is None
# --- scraping tables takes 101.75980353355408 seconds ---
# --- formatting first table takes 101.75980353355408 seconds ---
# --- formatting second table takes 101.75980353355408 seconds ---
# David Price
# https://www.fangraphs.com/players/david-price/3184/ table_advanced is None
# --- scraping tables takes 105.7123589515686 seconds ---
# --- formatting first table takes 105.7123589515686 seconds ---
# --- formatting second table takes 105.7123589515686 seconds ---
# Edwin Ríos
# --- scraping tables takes 107.9198989868164 seconds ---
# --- formatting first table takes 107.93485903739929 seconds ---
# --- formatting second table takes 107.94882202148438 seconds ---
# Kevin Pillar
# --- scraping tables takes 109.89337706565857 seconds ---
# --- formatting first table takes 109.90434789657593 seconds ---
# --- formatting second table takes 109.91531872749329 seconds ---
# Chris Taylor
# --- scraping tables takes 111.80029344558716 seconds ---
# --- formatting first table takes 111.81126379966736 seconds ---
# --- formatting second table takes 111.8222348690033 seconds ---
# Walker Buehler
# https://www.fangraphs.com/players/walker-buehler/19374/ table_advanced is None
# --- scraping tables takes 116.31740355491638 seconds ---
# --- formatting first table takes 116.31740355491638 seconds ---
# --- formatting second table takes 116.31740355491638 seconds ---
# Andrew Heaney
# https://www.fangraphs.com/players/andrew-heaney/15423/ table_advanced is None
# --- scraping tables takes 120.64263987541199 seconds ---
# --- formatting first table takes 120.64263987541199 seconds ---
# --- formatting second table takes 120.64263987541199 seconds ---
# Dustin May
# https://www.fangraphs.com/players/dustin-may/19716/ table_advanced is None
# --- scraping tables takes 124.2584707736969 seconds ---
# --- formatting first table takes 124.2584707736969 seconds ---
# --- formatting second table takes 124.2584707736969 seconds ---
# Danny Duffy
# https://www.fangraphs.com/players/danny-duffy/3542/ table_advanced is None
# --- scraping tables takes 128.95755696296692 seconds ---
# --- formatting first table takes 128.95755696296692 seconds ---
# --- formatting second table takes 128.95855498313904 seconds ---
# Victor González
# https://www.fangraphs.com/players/victor-gonzalez/16408/ table_advanced is None
# --- scraping tables takes 133.48122572898865 seconds ---
# --- formatting first table takes 133.48122572898865 seconds ---
# --- formatting second table takes 133.48122572898865 seconds ---
# Daniel Hudson
# https://www.fangraphs.com/players/daniel-hudson/7146/ table_advanced is None
# --- scraping tables takes 139.148912191391 seconds ---
# --- formatting first table takes 139.148912191391 seconds ---
# --- formatting second table takes 139.148912191391 seconds ---
# Tommy Kahnle
# https://www.fangraphs.com/players/tommy-kahnle/11384/ table_advanced is None
# --- scraping tables takes 144.9966058731079 seconds ---
# --- formatting first table takes 144.9966058731079 seconds ---
# --- formatting second table takes 144.9966058731079 seconds ---
# Jimmy Nelson
# https://www.fangraphs.com/players/jimmy-nelson/10547/ table_advanced is None
# --- scraping tables takes 153.01361632347107 seconds ---
# --- formatting first table takes 153.01361632347107 seconds ---
# --- formatting second table takes 153.01361632347107 seconds ---
# Blake Treinen
# https://www.fangraphs.com/players/blake-treinen/12572/ table_advanced is None
# --- scraping tables takes 157.6241352558136 seconds ---
# --- formatting first table takes 157.6241352558136 seconds ---
# --- formatting second table takes 157.6241352558136 seconds ---
# --- 159.91511249542236 seconds ---
# --- getting url takes 14.817468881607056 seconds ---
# Mookie Betts
# --- formatting second table takes 16.218252420425415 seconds ---
# Trea Turner
# --- formatting second table takes 17.942204475402832 seconds ---
# Freddie Freeman
# --- formatting second table takes 19.269712209701538 seconds ---
# Will Smith
# --- formatting second table takes 22.0683331489563 seconds ---
# Justin Turner
# --- formatting second table takes 23.088733911514282 seconds ---
# Cody Bellinger
# --- formatting second table takes 24.811150550842285 seconds ---
# Max Muncy
# --- formatting second table takes 25.756165742874146 seconds ---
# Jake Lamb
# --- formatting second table takes 26.58395028114319 seconds ---
# Gavin Lux
# --- formatting second table takes 28.431678533554077 seconds ---
# Austin Barnes
# --- formatting second table takes 31.009824991226196 seconds ---
# Hanser Alberto
# --- formatting second table takes 32.42314672470093 seconds ---
# Zach McKinstry
# --- formatting second table takes 34.290796518325806 seconds ---
# Trayce Thompson
# --- formatting second table takes 35.9752254486084 seconds ---
# Clayton Kershaw
# --- formatting second table takes 38.65676021575928 seconds ---
# Julio Urías
# --- formatting second table takes 40.34481954574585 seconds ---
# Mitch White
# --- formatting second table takes 41.66391968727112 seconds ---
# Tony Gonsolin
# --- formatting second table takes 43.32652497291565 seconds ---
# Tyler Anderson
# --- formatting second table takes 44.975210428237915 seconds ---
# Craig Kimbrel
# --- formatting second table takes 46.89008593559265 seconds ---
# Brusdar Graterol
# --- formatting second table takes 48.38360023498535 seconds ---
# Evan Phillips
# --- formatting second table takes 49.993990421295166 seconds ---
# Alex Vesia
# --- formatting second table takes 51.71575117111206 seconds ---
# Yency Almonte
# --- formatting second table takes 53.091049671173096 seconds ---
# Phil Bickford
# --- formatting second table takes 55.69805359840393 seconds ---
# Caleb Ferguson
# --- formatting second table takes 57.27016091346741 seconds ---
# David Price
# --- formatting second table takes 58.939916133880615 seconds ---
# Edwin Ríos
# --- formatting second table takes 61.06621599197388 seconds ---
# Kevin Pillar
# --- formatting second table takes 62.20928955078125 seconds ---
# Chris Taylor
# --- formatting second table takes 64.95498204231262 seconds ---
# Walker Buehler
# --- formatting second table takes 68.01391959190369 seconds ---
# Andrew Heaney
# --- formatting second table takes 69.70782995223999 seconds ---
# Dustin May
# --- formatting second table takes 71.02933120727539 seconds ---
# Danny Duffy
# --- formatting second table takes 72.30468153953552 seconds ---
# Victor González
# --- formatting second table takes 73.28671193122864 seconds ---
# Daniel Hudson
# --- formatting second table takes 76.02201461791992 seconds ---
# Tommy Kahnle
# --- formatting second table takes 77.27276396751404 seconds ---
# Jimmy Nelson
# --- formatting second table takes 79.54856443405151 seconds ---
# Blake Treinen
# --- formatting second table takes 80.65214157104492 seconds ---
# --- 82.638845205307 seconds ---
# --- getting url takes 14.917089462280273 seconds ---
# Joey Wendle
# --- scraping tables takes 16.578144073486328 seconds ---
# --- formatting first table takes 16.588117361068726 seconds ---
# --- formatting second table takes 16.600061655044556 seconds ---
# Jon Berti
# --- scraping tables takes 19.57593560218811 seconds ---
# --- formatting first table takes 19.588899612426758 seconds ---
# --- formatting second table takes 19.601863861083984 seconds ---
# Garrett Cooper
# --- scraping tables takes 21.46730875968933 seconds ---
# --- formatting first table takes 21.480273485183716 seconds ---
# --- formatting second table takes 21.493239879608154 seconds ---
# Jesús Aguilar
# --- scraping tables takes 24.492913722991943 seconds ---
# --- formatting first table takes 24.50388479232788 seconds ---
# --- formatting second table takes 24.5158531665802 seconds ---
# Avisaíl García
# --- scraping tables takes 26.683993577957153 seconds ---
# --- formatting first table takes 26.694963932037354 seconds ---
# --- formatting second table takes 26.705934762954712 seconds ---
# Brian Anderson
# --- scraping tables takes 28.521655559539795 seconds ---
# --- formatting first table takes 28.5326247215271 seconds ---
# --- formatting second table takes 28.545589923858643 seconds ---
# Jesús Sánchez
# --- scraping tables takes 30.288256883621216 seconds ---
# --- formatting first table takes 30.29922914505005 seconds ---
# --- formatting second table takes 30.312193870544434 seconds ---
# Miguel Rojas
# --- scraping tables takes 32.17975187301636 seconds ---
# --- formatting first table takes 32.192692279815674 seconds ---
# --- formatting second table takes 32.20466184616089 seconds ---
# Jacob Stallings
# --- scraping tables takes 34.002535581588745 seconds ---
# --- formatting first table takes 34.01450443267822 seconds ---
# --- formatting second table takes 34.03445243835449 seconds ---
# Nick Fortes
# --- scraping tables takes 35.71245098114014 seconds ---
# --- formatting first table takes 35.723422050476074 seconds ---
# --- formatting second table takes 35.734392404556274 seconds ---
# Luke Williams
# --- scraping tables takes 37.941476583480835 seconds ---
# --- formatting first table takes 37.95344400405884 seconds ---
# --- formatting second table takes 37.96541237831116 seconds ---
# Bryan De La Cruz
# --- scraping tables takes 40.045918226242065 seconds ---
# --- formatting first table takes 40.05589056015015 seconds ---
# --- formatting second table takes 40.06785774230957 seconds ---
# Billy Hamilton
# --- scraping tables takes 41.94767189025879 seconds ---
# --- formatting first table takes 41.95964169502258 seconds ---
# --- formatting second table takes 41.97360277175903 seconds ---
# Sandy Alcantara
# https://www.fangraphs.com/players/sandy-alcantara/18684/ table_advanced is None
# --- scraping tables takes 45.82874274253845 seconds ---
# --- formatting first table takes 45.82874274253845 seconds ---
# --- formatting second table takes 45.82874274253845 seconds ---
# Trevor Rogers
# https://www.fangraphs.com/players/trevor-rogers/22286/ table_advanced is None
# --- scraping tables takes 51.301419734954834 seconds ---
# --- formatting first table takes 51.301419734954834 seconds ---
# --- formatting second table takes 51.301419734954834 seconds ---
# Daniel Castano
# https://www.fangraphs.com/players/daniel-castano/19805/ table_advanced is None
# --- scraping tables takes 56.27491021156311 seconds ---
# --- formatting first table takes 56.27491021156311 seconds ---
# --- formatting second table takes 56.27491021156311 seconds ---
# Pablo López
# https://www.fangraphs.com/players/pablo-lopez/17085/ table_advanced is None
# --- scraping tables takes 60.79289174079895 seconds ---
# --- formatting first table takes 60.79289174079895 seconds ---
# --- formatting second table takes 60.79289174079895 seconds ---
# Braxton Garrett
# https://www.fangraphs.com/players/braxton-garrett/21844/ table_advanced is None
# --- scraping tables takes 65.31160259246826 seconds ---
# --- formatting first table takes 65.31160259246826 seconds ---
# --- formatting second table takes 65.31160259246826 seconds ---
# Tanner Scott
# https://www.fangraphs.com/players/tanner-scott/17586/ table_advanced is None
# --- scraping tables takes 69.6369857788086 seconds ---
# --- formatting first table takes 69.6369857788086 seconds ---
# --- formatting second table takes 69.6369857788086 seconds ---
# Anthony Bass
# https://www.fangraphs.com/players/anthony-bass/7982/ table_advanced is None
# --- scraping tables takes 73.53129243850708 seconds ---
# --- formatting first table takes 73.53129243850708 seconds ---
# --- formatting second table takes 73.53129243850708 seconds ---
# Steven Okert
# https://www.fangraphs.com/players/steven-okert/13580/ table_advanced is None
# --- scraping tables takes 77.45150518417358 seconds ---
# --- formatting first table takes 77.45150518417358 seconds ---
# --- formatting second table takes 77.45150518417358 seconds ---
# Dylan Floro
# https://www.fangraphs.com/players/dylan-floro/13394/ table_advanced is None
# --- scraping tables takes 81.52672076225281 seconds ---
# --- formatting first table takes 81.52672076225281 seconds ---
# --- formatting second table takes 81.52672076225281 seconds ---
# Jimmy Yacabonis
# https://www.fangraphs.com/players/jimmy-yacabonis/15157/ table_advanced is None
# --- scraping tables takes 87.24580121040344 seconds ---
# --- formatting first table takes 87.24580121040344 seconds ---
# --- formatting second table takes 87.24580121040344 seconds ---
# Zach Pop
# https://www.fangraphs.com/players/zach-pop/20185/ table_advanced is None
# --- scraping tables takes 92.0259439945221 seconds ---
# --- formatting first table takes 92.0259439945221 seconds ---
# --- formatting second table takes 92.0259439945221 seconds ---
# Richard Bleier
# https://www.fangraphs.com/players/richard-bleier/7803/ table_advanced is None
# --- scraping tables takes 96.57936453819275 seconds ---
# --- formatting first table takes 96.57936453819275 seconds ---
# --- formatting second table takes 96.57936453819275 seconds ---
# Elieser Hernandez
# https://www.fangraphs.com/players/elieser-hernandez/16933/ table_advanced is None
# --- scraping tables takes 101.18665766716003 seconds ---
# --- formatting first table takes 101.18765473365784 seconds ---
# --- formatting second table takes 101.18765473365784 seconds ---
# Jazz Chisholm Jr.
# --- scraping tables takes 103.21234679222107 seconds ---
# --- formatting first table takes 103.22431659698486 seconds ---
# --- formatting second table takes 103.23628401756287 seconds ---
# Jorge Soler
# --- scraping tables takes 104.80704069137573 seconds ---
# --- formatting first table takes 104.81801223754883 seconds ---
# --- formatting second table takes 104.83496522903442 seconds ---
# Edward Cabrera
# https://www.fangraphs.com/players/edward-cabrera/21690/ table_advanced is None
# --- scraping tables takes 109.20945024490356 seconds ---
# --- formatting first table takes 109.20945024490356 seconds ---
# --- formatting second table takes 109.20945024490356 seconds ---
# Jesús Luzardo
# https://www.fangraphs.com/players/jesus-luzardo/19959/ table_advanced is None
# --- scraping tables takes 114.00749635696411 seconds ---
# --- formatting first table takes 114.00749635696411 seconds ---
# --- formatting second table takes 114.00749635696411 seconds ---
# Cody Poteet
# https://www.fangraphs.com/players/cody-poteet/18769/ table_advanced is None
# --- scraping tables takes 118.97217392921448 seconds ---
# --- formatting first table takes 118.97217392921448 seconds ---
# --- formatting second table takes 118.97217392921448 seconds ---
# Anthony Bender
# https://www.fangraphs.com/players/anthony-bender/19742/ table_advanced is None
# --- scraping tables takes 124.23106861114502 seconds ---
# --- formatting first table takes 124.23206448554993 seconds ---
# --- formatting second table takes 124.23206448554993 seconds ---
# Paul Campbell
# https://www.fangraphs.com/players/paul-campbell/22248/ table_advanced is None
# --- scraping tables takes 129.2282009124756 seconds ---
# --- formatting first table takes 129.2282009124756 seconds ---
# --- formatting second table takes 129.22920298576355 seconds ---
# Sean Guenther
# https://www.fangraphs.com/players/sean-guenther/20045/ table_advanced is None
# --- scraping tables takes 134.06171107292175 seconds ---
# --- formatting first table takes 134.06171107292175 seconds ---
# --- formatting second table takes 134.06171107292175 seconds ---
# Cole Sulser
# https://www.fangraphs.com/players/cole-sulser/15256/ table_advanced is None
# --- scraping tables takes 138.80589842796326 seconds ---
# --- formatting first table takes 138.80589842796326 seconds ---
# --- formatting second table takes 138.80589842796326 seconds ---
# --- 141.41348147392273 seconds ---
# --- getting url takes 14.536080837249756 seconds ---
# Joey Wendle
# --- formatting second table takes 17.324772834777832 seconds ---
# Jon Berti
# --- formatting second table takes 19.67491841316223 seconds ---
# Garrett Cooper
# --- formatting second table takes 20.97605061531067 seconds ---
# Jesús Aguilar
# --- formatting second table takes 22.707139015197754 seconds ---
# Avisaíl García
# --- formatting second table takes 25.28126311302185 seconds ---
# Brian Anderson
# --- formatting second table takes 26.437955856323242 seconds ---
# Jesús Sánchez
# --- formatting second table takes 27.735613107681274 seconds ---
# Miguel Rojas
# --- formatting second table takes 29.071031093597412 seconds ---
# Jacob Stallings
# --- formatting second table takes 31.586331367492676 seconds ---
# Nick Fortes
# --- formatting second table takes 32.900580167770386 seconds ---
# Luke Williams
# --- formatting second table takes 34.155033111572266 seconds ---
# Bryan De La Cruz
# --- formatting second table takes 36.01381468772888 seconds ---
# Billy Hamilton
# --- formatting second table takes 37.72829723358154 seconds ---
# Sandy Alcantara
# --- formatting second table takes 39.34002709388733 seconds ---
# Trevor Rogers
# --- formatting second table takes 41.073389768600464 seconds ---
# Daniel Castano
# --- formatting second table takes 42.46466612815857 seconds ---
# Pablo López
# --- formatting second table takes 44.229941844940186 seconds ---
# Braxton Garrett
# --- formatting second table takes 45.84960699081421 seconds ---
# Tanner Scott
# --- formatting second table takes 47.720600605010986 seconds ---
# Anthony Bass
# --- formatting second table takes 49.33029580116272 seconds ---
# Steven Okert
# --- formatting second table takes 50.983871936798096 seconds ---
# Dylan Floro
# --- formatting second table takes 53.94844627380371 seconds ---
# Jimmy Yacabonis
# --- formatting second table takes 55.4369912147522 seconds ---
# Zach Pop
# --- formatting second table takes 57.011760234832764 seconds ---
# Richard Bleier
# --- formatting second table takes 58.64362621307373 seconds ---
# Elieser Hernandez
# --- formatting second table takes 59.996020555496216 seconds ---
# Jazz Chisholm Jr.
# --- formatting second table takes 61.651092529296875 seconds ---
# Jorge Soler
# --- formatting second table takes 62.862462759017944 seconds ---
# Edward Cabrera
# --- formatting second table takes 64.4672908782959 seconds ---
# Jesús Luzardo
# --- formatting second table takes 66.54202771186829 seconds ---
# Cody Poteet
# --- formatting second table takes 68.1093761920929 seconds ---
# Anthony Bender
# --- formatting second table takes 69.81402444839478 seconds ---
# Paul Campbell
# --- formatting second table takes 71.08812522888184 seconds ---
# Sean Guenther
# --- formatting second table takes 72.41465353965759 seconds ---
# Cole Sulser
# --- formatting second table takes 73.94608640670776 seconds ---
# --- 76.2372658252716 seconds ---
# --- getting url takes 14.61817979812622 seconds ---
# Christian Yelich
# --- scraping tables takes 16.362650632858276 seconds ---
# --- formatting first table takes 16.372623920440674 seconds ---
# --- formatting second table takes 16.38359546661377 seconds ---
# Willy Adames
# --- scraping tables takes 18.27055072784424 seconds ---
# --- formatting first table takes 18.28650736808777 seconds ---
# --- formatting second table takes 18.303462982177734 seconds ---
# Rowdy Tellez
# --- scraping tables takes 20.039326429367065 seconds ---
# --- formatting first table takes 20.049299716949463 seconds ---
# --- formatting second table takes 20.060271978378296 seconds ---
# Andrew McCutchen
# --- scraping tables takes 23.35917568206787 seconds ---
# --- formatting first table takes 23.36915111541748 seconds ---
# --- formatting second table takes 23.380119562149048 seconds ---
# Kolten Wong
# --- scraping tables takes 25.07555627822876 seconds ---
# --- formatting first table takes 25.088521003723145 seconds ---
# --- formatting second table takes 25.101486206054688 seconds ---
# Luis Urías
# --- scraping tables takes 26.75386095046997 seconds ---
# --- formatting first table takes 26.764859199523926 seconds ---
# --- formatting second table takes 26.77679967880249 seconds ---
# Jace Peterson
# --- scraping tables takes 29.144359588623047 seconds ---
# --- formatting first table takes 29.160292863845825 seconds ---
# --- formatting second table takes 29.17228865623474 seconds ---
# Hunter Renfroe
# --- scraping tables takes 30.847597122192383 seconds ---
# --- formatting first table takes 30.857542514801025 seconds ---
# --- formatting second table takes 30.872503519058228 seconds ---
# Omar Narváez
# --- scraping tables takes 33.21119523048401 seconds ---
# --- formatting first table takes 33.22213578224182 seconds ---
# --- formatting second table takes 33.233108043670654 seconds ---
# Victor Caratini
# --- scraping tables takes 35.20646548271179 seconds ---
# --- formatting first table takes 35.21643924713135 seconds ---
# --- formatting second table takes 35.22937607765198 seconds ---
# Pedro Severino
# --- scraping tables takes 36.97763013839722 seconds ---
# --- formatting first table takes 36.98264455795288 seconds ---
# --- formatting second table takes 36.98960041999817 seconds ---
# Mike Brosseau
# --- scraping tables takes 38.754608392715454 seconds ---
# --- formatting first table takes 38.76757478713989 seconds ---
# --- formatting second table takes 38.78253364562988 seconds ---
# Jonathan Davis
# --- scraping tables takes 40.57162690162659 seconds ---
# --- formatting first table takes 40.58758497238159 seconds ---
# --- formatting second table takes 40.598554849624634 seconds ---
# Corbin Burnes
# https://www.fangraphs.com/players/corbin-burnes/19361/ table_advanced is None
# --- scraping tables takes 44.41998767852783 seconds ---
# --- formatting first table takes 44.41998767852783 seconds ---
# --- formatting second table takes 44.41998767852783 seconds ---
# Brandon Woodruff
# https://www.fangraphs.com/players/brandon-woodruff/16162/ table_advanced is None
# --- scraping tables takes 48.94436812400818 seconds ---
# --- formatting first table takes 48.94436812400818 seconds ---
# --- formatting second table takes 48.94436812400818 seconds ---
# Eric Lauer
# https://www.fangraphs.com/players/eric-lauer/19316/ table_advanced is None
# --- scraping tables takes 53.547903537750244 seconds ---
# --- formatting first table takes 53.547903537750244 seconds ---
# --- formatting second table takes 53.547903537750244 seconds ---
# Jason Alexander
# https://www.fangraphs.com/players/jason-alexander/19666/ table_advanced is None
# --- scraping tables takes 57.82247853279114 seconds ---
# --- formatting first table takes 57.82247853279114 seconds ---
# --- formatting second table takes 57.82247853279114 seconds ---
# Aaron Ashby
# https://www.fangraphs.com/players/aaron-ashby/23550/ table_advanced is None
# --- scraping tables takes 62.047356843948364 seconds ---
# --- formatting first table takes 62.047356843948364 seconds ---
# --- formatting second table takes 62.047356843948364 seconds ---
# Josh Hader
# https://www.fangraphs.com/players/josh-hader/14212/ table_advanced is None
# --- scraping tables takes 66.24684929847717 seconds ---
# --- formatting first table takes 66.24684929847717 seconds ---
# --- formatting second table takes 66.24684929847717 seconds ---
# Devin Williams
# https://www.fangraphs.com/players/devin-williams/15816/ table_advanced is None
# --- scraping tables takes 70.64348244667053 seconds ---
# --- formatting first table takes 70.64348244667053 seconds ---
# --- formatting second table takes 70.64348244667053 seconds ---
# Brad Boxberger
# https://www.fangraphs.com/players/brad-boxberger/10133/ table_advanced is None
# --- scraping tables takes 77.04976081848145 seconds ---
# --- formatting first table takes 77.04976081848145 seconds ---
# --- formatting second table takes 77.04976081848145 seconds ---
# Trevor Gott
# https://www.fangraphs.com/players/trevor-gott/15046/ table_advanced is None
# --- scraping tables takes 83.10872888565063 seconds ---
# --- formatting first table takes 83.10872888565063 seconds ---
# --- formatting second table takes 83.10872888565063 seconds ---
# Brent Suter
# https://www.fangraphs.com/players/brent-suter/13942/ table_advanced is None
# --- scraping tables takes 88.9886634349823 seconds ---
# --- formatting first table takes 88.9886634349823 seconds ---
# --- formatting second table takes 88.9886634349823 seconds ---
# Hoby Milner
# https://www.fangraphs.com/players/hoby-milner/13346/ table_advanced is None
# --- scraping tables takes 94.03520512580872 seconds ---
# --- formatting first table takes 94.03620219230652 seconds ---
# --- formatting second table takes 94.03620219230652 seconds ---
# Connor Sadzeck
# https://www.fangraphs.com/players/connor-sadzeck/13483/ table_advanced is None
# --- scraping tables takes 97.7115159034729 seconds ---
# --- formatting first table takes 97.7115159034729 seconds ---
# --- formatting second table takes 97.7115159034729 seconds ---
# Jandel Gustave
# https://www.fangraphs.com/players/jandel-gustave/14665/ table_advanced is None
# --- scraping tables takes 102.44236755371094 seconds ---
# --- formatting first table takes 102.44236755371094 seconds ---
# --- formatting second table takes 102.44236755371094 seconds ---
# Alex Jackson
# --- scraping tables takes 105.13561391830444 seconds ---
# --- formatting first table takes 105.14758324623108 seconds ---
# --- formatting second table takes 105.15755534172058 seconds ---
# Tyrone Taylor
# --- scraping tables takes 106.9301164150238 seconds ---
# --- formatting first table takes 106.94108748435974 seconds ---
# --- formatting second table takes 106.95205760002136 seconds ---
# Adrian Houser
# https://www.fangraphs.com/players/adrian-houser/12718/ table_advanced is None
# --- scraping tables takes 113.6777834892273 seconds ---
# --- formatting first table takes 113.6777834892273 seconds ---
# --- formatting second table takes 113.6777834892273 seconds ---
# Freddy Peralta
# https://www.fangraphs.com/players/freddy-peralta/18679/ table_advanced is None
# --- scraping tables takes 119.07545614242554 seconds ---
# --- formatting first table takes 119.07645320892334 seconds ---
# --- formatting second table takes 119.07645320892334 seconds ---
# Jake Cousins
# https://www.fangraphs.com/players/jake-cousins/21620/ table_advanced is None
# --- scraping tables takes 124.50047445297241 seconds ---
# --- formatting first table takes 124.50047445297241 seconds ---
# --- formatting second table takes 124.50047445297241 seconds ---
# Luis Perdomo
# https://www.fangraphs.com/players/luis-perdomo/14682/ table_advanced is None
# --- scraping tables takes 130.31530952453613 seconds ---
# --- formatting first table takes 130.31530952453613 seconds ---
# --- formatting second table takes 130.31530952453613 seconds ---
# Miguel Sánchez
# https://www.fangraphs.com/players/miguel-sanchez/20074/ table_advanced is None
# --- scraping tables takes 135.79146480560303 seconds ---
# --- formatting first table takes 135.79146480560303 seconds ---
# --- formatting second table takes 135.79146480560303 seconds ---
# Justin Topa
# https://www.fangraphs.com/players/justin-topa/15145/ table_advanced is None
# --- scraping tables takes 140.29398608207703 seconds ---
# --- formatting first table takes 140.29398608207703 seconds ---
# --- formatting second table takes 140.29398608207703 seconds ---
# --- 142.6331660747528 seconds ---
# --- getting url takes 17.16434121131897 seconds ---
# Christian Yelich
# --- formatting second table takes 18.493047952651978 seconds ---
# Willy Adames
# --- formatting second table takes 19.793333530426025 seconds ---
# Rowdy Tellez
# --- formatting second table takes 21.58371925354004 seconds ---
# Andrew McCutchen
# --- formatting second table takes 23.18222403526306 seconds ---
# Kolten Wong
# --- formatting second table takes 24.56951880455017 seconds ---
# Luis Urías
# --- formatting second table takes 25.754156351089478 seconds ---
# Jace Peterson
# --- formatting second table takes 28.124404668807983 seconds ---
# Hunter Renfroe
# --- formatting second table takes 29.813729763031006 seconds ---
# Omar Narváez
# --- formatting second table takes 31.181892156600952 seconds ---
# Victor Caratini
# --- formatting second table takes 32.18694734573364 seconds ---
# Pedro Severino
# --- formatting second table takes 33.36778903007507 seconds ---
# Mike Brosseau
# --- formatting second table takes 35.14875030517578 seconds ---
# Jonathan Davis
# --- formatting second table takes 37.620219707489014 seconds ---
# Corbin Burnes
# --- formatting second table takes 38.92432641983032 seconds ---
# Brandon Woodruff
# --- formatting second table takes 40.33664298057556 seconds ---
# Eric Lauer
# --- formatting second table takes 41.56438684463501 seconds ---
# Jason Alexander
# --- formatting second table takes 43.008912086486816 seconds ---
# Aaron Ashby
# --- formatting second table takes 44.34080791473389 seconds ---
# Josh Hader
# --- formatting second table takes 45.683517932891846 seconds ---
# Devin Williams
# --- formatting second table takes 47.39897871017456 seconds ---
# Brad Boxberger
# --- formatting second table takes 48.98279881477356 seconds ---
# Trevor Gott
# --- formatting second table takes 50.261730909347534 seconds ---
# Brent Suter
# --- formatting second table takes 52.06197953224182 seconds ---
# Hoby Milner
# --- formatting second table takes 54.98428964614868 seconds ---
# Connor Sadzeck
# --- formatting second table takes 56.260494232177734 seconds ---
# Jandel Gustave
# --- formatting second table takes 57.958245038986206 seconds ---
# Alex Jackson
# --- formatting second table takes 59.29759979248047 seconds ---
# Tyrone Taylor
# --- formatting second table takes 61.0253586769104 seconds ---
# Adrian Houser
# --- formatting second table takes 62.43851900100708 seconds ---
# Freddy Peralta
# --- formatting second table takes 65.34670162200928 seconds ---
# Jake Cousins
# --- formatting second table takes 66.7825403213501 seconds ---
# Luis Perdomo
# --- formatting second table takes 68.09471225738525 seconds ---
# Miguel Sánchez
# --- formatting second table takes 69.54081583023071 seconds ---
# Justin Topa
# --- formatting second table takes 71.92908525466919 seconds ---
# --- 74.1858720779419 seconds ---
# --- getting url takes 15.005540132522583 seconds ---
# Brandon Nimmo
# --- scraping tables takes 17.063145399093628 seconds ---
# --- formatting first table takes 17.073123693466187 seconds ---
# --- formatting second table takes 17.083091259002686 seconds ---
# Starling Marte
# --- scraping tables takes 19.167664527893066 seconds ---
# --- formatting first table takes 19.17766571044922 seconds ---
# --- formatting second table takes 19.188644647598267 seconds ---
# Francisco Lindor
# --- scraping tables takes 20.96832036972046 seconds ---
# --- formatting first table takes 20.980287551879883 seconds ---
# --- formatting second table takes 20.99524736404419 seconds ---
# Pete Alonso
# --- scraping tables takes 22.743407487869263 seconds ---
# --- formatting first table takes 22.754382371902466 seconds ---
# --- formatting second table takes 22.765352964401245 seconds ---
# Luis Guillorme
# --- scraping tables takes 24.54244637489319 seconds ---
# --- formatting first table takes 24.552419424057007 seconds ---
# --- formatting second table takes 24.563390254974365 seconds ---
# Mark Canha
# --- scraping tables takes 26.4518780708313 seconds ---
# --- formatting first table takes 26.46284770965576 seconds ---
# --- formatting second table takes 26.47980260848999 seconds ---
# Dominic Smith
# --- scraping tables takes 29.24885129928589 seconds ---
# --- formatting first table takes 29.258848190307617 seconds ---
# --- formatting second table takes 29.270824193954468 seconds ---
# Eduardo Escobar
# --- scraping tables takes 31.13415026664734 seconds ---
# --- formatting first table takes 31.144123315811157 seconds ---
# --- formatting second table takes 31.15509343147278 seconds ---
# Tomás Nido
# --- scraping tables takes 34.31358075141907 seconds ---
# --- formatting first table takes 34.32365322113037 seconds ---
# --- formatting second table takes 34.33864188194275 seconds ---
# Patrick Mazeika
# --- scraping tables takes 36.33753228187561 seconds ---
# --- formatting first table takes 36.34950065612793 seconds ---
# --- formatting second table takes 36.36146879196167 seconds ---
# J.D. Davis
# --- scraping tables takes 39.361109018325806 seconds ---
# --- formatting first table takes 39.37208008766174 seconds ---
# --- formatting second table takes 39.38304901123047 seconds ---
# Ender Inciarte
# --- scraping tables takes 41.045167684555054 seconds ---
# --- formatting first table takes 41.05514192581177 seconds ---
# --- formatting second table takes 41.066274881362915 seconds ---
# Travis Jankowski
# --- scraping tables takes 43.27525782585144 seconds ---
# --- formatting first table takes 43.290218114852905 seconds ---
# ...
# --- formatting first table takes 121.98644995689392 seconds ---
# --- formatting second table takes 121.98644995689392 seconds ---
# --- 124.34713196754456 seconds ---
# --- getting url takes 17.54017186164856 seconds ---
# Brendan Donovan
# --- formatting second table takes 18.82342267036438 seconds ---
# Dylan Carlson
# --- formatting second table takes 20.54180097579956 seconds ---
# Paul Goldschmidt
# --- formatting second table takes 21.720646619796753 seconds ---
# Nolan Arenado
# --- formatting second table takes 23.679404497146606 seconds ---
# Nolan Gorman
# --- formatting second table takes 24.571019172668457 seconds ---
# Tommy Edman
# --- formatting second table takes 26.27545738220215 seconds ---
# Juan Yepez
# --- formatting second table takes 28.001917839050293 seconds ---
# Corey Dickerson
# --- formatting second table takes 30.35269832611084 seconds ---
# Andrew Knizner
# --- formatting second table takes 31.691116094589233 seconds ---
# Austin Romine
# --- formatting second table takes 33.17418122291565 seconds ---
# Albert Pujols
# --- formatting second table takes 34.584476709365845 seconds ---
# Edmundo Sosa
# --- formatting second table takes 35.96478247642517 seconds ---
# Lars Nootbaar
# --- formatting second table takes 37.970414876937866 seconds ---
# Adam Wainwright
# --- formatting second table takes 39.20311784744263 seconds ---
# Dakota Hudson
# --- formatting second table takes 40.932488441467285 seconds ---
# Andre Pallante
# --- formatting second table takes 42.43945527076721 seconds ---
# Miles Mikolas
# --- formatting second table takes 44.113975524902344 seconds ---
# Ryan Helsley
# --- formatting second table takes 45.77951717376709 seconds ---
# Giovanny Gallegos
# --- formatting second table takes 48.33969449996948 seconds ---
# Génesis Cabrera
# --- formatting second table takes 49.67010569572449 seconds ---
# Jordan Hicks
# --- formatting second table takes 51.69468903541565 seconds ---
# Junior Fernández
# --- formatting second table takes 52.934370279312134 seconds ---
# Johan Oviedo
# --- formatting second table takes 54.4642767906189 seconds ---
# T.J. McFarland
# --- formatting second table takes 56.28540301322937 seconds ---
# Packy Naughton
# --- formatting second table takes 57.60985851287842 seconds ---
# Drew VerHagen
# --- formatting second table takes 59.26044154167175 seconds ---
# Yadier Molina
# --- formatting second table takes 60.736491203308105 seconds ---
# Harrison Bader
# --- formatting second table takes 62.399044036865234 seconds ---
# Tyler O'Neill
# --- formatting second table takes 63.80727434158325 seconds ---
# Jack Flaherty
# --- formatting second table takes 65.19954824447632 seconds ---
# Steven Matz
# --- formatting second table takes 66.60179567337036 seconds ---
# Alex Reyes
# --- formatting second table takes 69.02236032485962 seconds ---
# --- 71.09486627578735 seconds ---
# --- getting url takes 17.873285055160522 seconds ---
# Luis García
# --- scraping tables takes 19.431148529052734 seconds ---
# --- formatting first table takes 19.44308614730835 seconds ---
# --- formatting second table takes 19.45805597305298 seconds ---
# Josh Bell
# --- scraping tables takes 21.319063901901245 seconds ---
# --- formatting first table takes 21.32804012298584 seconds ---
# --- formatting second table takes 21.34000825881958 seconds ---
# Juan Soto
# --- scraping tables takes 23.48127794265747 seconds ---
# --- formatting first table takes 23.49224853515625 seconds ---
# --- formatting second table takes 23.50421643257141 seconds ---
# Nelson Cruz
# --- scraping tables takes 25.093962907791138 seconds ---
# --- formatting first table takes 25.105931997299194 seconds ---
# --- formatting second table takes 25.117899656295776 seconds ---
# Yadiel Hernandez
# --- scraping tables takes 27.49354124069214 seconds ---
# --- formatting first table takes 27.508500576019287 seconds ---
# --- formatting second table takes 27.519471645355225 seconds ---
# César Hernández
# --- scraping tables takes 29.259815216064453 seconds ---
# --- formatting first table takes 29.274775743484497 seconds ---
# --- formatting second table takes 29.29472303390503 seconds ---
# Keibert Ruiz
# --- scraping tables takes 31.01414918899536 seconds ---
# --- formatting first table takes 31.025092124938965 seconds ---
# --- formatting second table takes 31.04005002975464 seconds ---
# Maikel Franco
# --- scraping tables takes 33.22822284698486 seconds ---
# --- formatting first table takes 33.239168643951416 seconds ---
# --- formatting second table takes 33.26312780380249 seconds ---
# Lane Thomas
# --- scraping tables takes 35.133097887039185 seconds ---
# --- formatting first table takes 35.14706015586853 seconds ---
# --- formatting second table takes 35.15803050994873 seconds ---
# Tres Barrera
# --- scraping tables takes 36.80562114715576 seconds ---
# --- formatting first table takes 36.81659150123596 seconds ---
# --- formatting second table takes 36.8265655040741 seconds ---
# Alcides Escobar
# --- scraping tables takes 38.535990953445435 seconds ---
# --- formatting first table takes 38.55394268035889 seconds ---
# --- formatting second table takes 38.57488703727722 seconds ---
# Ehire Adrianza
# --- scraping tables takes 40.37207841873169 seconds ---
# --- formatting first table takes 40.384047508239746 seconds ---
# --- formatting second table takes 40.39900732040405 seconds ---
# Victor Robles
# --- scraping tables takes 43.53760600090027 seconds ---
# --- formatting first table takes 43.54857659339905 seconds ---
# --- formatting second table takes 43.55954718589783 seconds ---
# Josiah Gray
# https://www.fangraphs.com/players/josiah-gray/24580/ table_advanced is None
# --- scraping tables takes 47.48452973365784 seconds ---
# --- formatting first table takes 47.48452973365784 seconds ---
# --- formatting second table takes 47.48452973365784 seconds ---
# Erick Fedde
# https://www.fangraphs.com/players/erick-fedde/17425/ table_advanced is None
# --- scraping tables takes 51.745566844940186 seconds ---
# --- formatting first table takes 51.745566844940186 seconds ---
# --- formatting second table takes 51.745566844940186 seconds ---
# Patrick Corbin
# https://www.fangraphs.com/players/patrick-corbin/9323/ table_advanced is None
# --- scraping tables takes 55.798696994781494 seconds ---
# --- formatting first table takes 55.798696994781494 seconds ---
# --- formatting second table takes 55.798696994781494 seconds ---
# Paolo Espino
# https://www.fangraphs.com/players/paolo-espino/8246/ table_advanced is None
# --- scraping tables takes 59.66555571556091 seconds ---
# --- formatting first table takes 59.66555571556091 seconds ---
# --- formatting second table takes 59.66555571556091 seconds ---
# Kyle Finnegan
# https://www.fangraphs.com/players/kyle-finnegan/15009/ table_advanced is None
# --- scraping tables takes 64.08173608779907 seconds ---
# --- formatting first table takes 64.08173608779907 seconds ---
# --- formatting second table takes 64.08173608779907 seconds ---
# Carl Edwards Jr.
# https://www.fangraphs.com/players/carl-edwards-jr/13607/ table_advanced is None
# --- scraping tables takes 68.33535385131836 seconds ---
# --- formatting first table takes 68.33535385131836 seconds ---
# --- formatting second table takes 68.33535385131836 seconds ---
# Steve Cishek
# https://www.fangraphs.com/players/steve-cishek/6483/ table_advanced is None
# --- scraping tables takes 72.85924649238586 seconds ---
# --- formatting first table takes 72.85924649238586 seconds ---
# --- formatting second table takes 72.85924649238586 seconds ---
# Andres Machado
# https://www.fangraphs.com/players/andres-machado/14681/ table_advanced is None
# --- scraping tables takes 78.11318612098694 seconds ---
# --- formatting first table takes 78.11318612098694 seconds ---
# --- formatting second table takes 78.11318612098694 seconds ---
# Mason Thompson
# https://www.fangraphs.com/players/mason-thompson/21850/ table_advanced is None
# --- scraping tables takes 83.32726263999939 seconds ---
# --- formatting first table takes 83.32726263999939 seconds ---
# --- formatting second table takes 83.32726263999939 seconds ---
# Jordan Weems
# https://www.fangraphs.com/players/jordan-weems/13190/ table_advanced is None
# --- scraping tables takes 86.87043166160583 seconds ---
# --- formatting first table takes 86.87142872810364 seconds ---
# --- formatting second table takes 86.87142872810364 seconds ---
# Hunter Harvey
# https://www.fangraphs.com/players/hunter-harvey/15507/ table_advanced is None
# --- scraping tables takes 91.09612488746643 seconds ---
# --- formatting first table takes 91.09612488746643 seconds ---
# --- formatting second table takes 91.09612488746643 seconds ---
# Tyler Clippard
# https://www.fangraphs.com/players/tyler-clippard/5640/ table_advanced is None
# --- scraping tables takes 95.32688617706299 seconds ---
# --- formatting first table takes 95.32688617706299 seconds ---
# --- formatting second table takes 95.32688617706299 seconds ---
# Erasmo Ramírez
# https://www.fangraphs.com/players/erasmo-ramirez/10314/ table_advanced is None
# --- scraping tables takes 99.84280133247375 seconds ---
# --- formatting first table takes 99.84280133247375 seconds ---
# --- formatting second table takes 99.84280133247375 seconds ---
# Cory Abbott
# https://www.fangraphs.com/players/cory-abbott/20277/ table_advanced is None
# --- scraping tables takes 105.0838074684143 seconds ---
# --- formatting first table takes 105.0838074684143 seconds ---
# --- formatting second table takes 105.0838074684143 seconds ---
# Carter Kieboom
# --- scraping tables takes 106.13299942016602 seconds ---
# --- formatting first table takes 106.13299942016602 seconds ---
# --- formatting second table takes 106.13299942016602 seconds ---
# Seth Romero
# https://www.fangraphs.com/players/seth-romero/21333/ table_advanced is None
# --- scraping tables takes 111.27726292610168 seconds ---
# --- formatting first table takes 111.27726292610168 seconds ---
# --- formatting second table takes 111.27726292610168 seconds ---
# Joe Ross
# https://www.fangraphs.com/players/joe-ross/12972/ table_advanced is None
# --- scraping tables takes 115.30548357963562 seconds ---
# --- formatting first table takes 115.30548357963562 seconds ---
# --- formatting second table takes 115.30548357963562 seconds ---
# Aníbal Sánchez
# https://www.fangraphs.com/players/anibal-sanchez/3284/ table_advanced is None
# --- scraping tables takes 119.6608293056488 seconds ---
# --- formatting first table takes 119.6608293056488 seconds ---
# --- formatting second table takes 119.6608293056488 seconds ---
# Stephen Strasburg
# https://www.fangraphs.com/players/stephen-strasburg/10131/ table_advanced is None
# --- scraping tables takes 123.56637644767761 seconds ---
# --- formatting first table takes 123.56637644767761 seconds ---
# --- formatting second table takes 123.56637644767761 seconds ---
# Jackson Tetreault
# https://www.fangraphs.com/players/jackson-tetreault/20565/ table_advanced is None
# --- scraping tables takes 128.23899149894714 seconds ---
# --- formatting first table takes 128.23899149894714 seconds ---
# --- formatting second table takes 128.23899149894714 seconds ---
# Víctor Arano
# https://www.fangraphs.com/players/victor-arano/15915/ table_advanced is None
# --- scraping tables takes 132.121600151062 seconds ---
# --- formatting first table takes 132.121600151062 seconds ---
# --- formatting second table takes 132.121600151062 seconds ---
# Sean Doolittle
# https://www.fangraphs.com/players/sean-doolittle/1581/ table_advanced is None
# --- scraping tables takes 136.0500590801239 seconds ---
# --- formatting first table takes 136.0500590801239 seconds ---
# --- formatting second table takes 136.0500590801239 seconds ---
# Reed Garrett
# https://www.fangraphs.com/players/reed-garrett/16866/ table_advanced is None
# --- scraping tables takes 140.16804003715515 seconds ---
# --- formatting first table takes 140.16903734207153 seconds ---
# --- formatting second table takes 140.16903734207153 seconds ---
# Will Harris
# https://www.fangraphs.com/players/will-harris/3192/ table_advanced is None
# --- scraping tables takes 143.83722233772278 seconds ---
# --- formatting first table takes 143.83722233772278 seconds ---
# --- formatting second table takes 143.83722233772278 seconds ---
# Evan Lee
# https://www.fangraphs.com/players/evan-lee/24988/ table_advanced is None
# --- scraping tables takes 149.44125366210938 seconds ---
# --- formatting first table takes 149.44125366210938 seconds ---
# --- formatting second table takes 149.44125366210938 seconds ---
# Tanner Rainey
# https://www.fangraphs.com/players/tanner-rainey/17610/ table_advanced is None
# --- scraping tables takes 153.8594319820404 seconds ---
# --- formatting first table takes 153.8594319820404 seconds ---
# --- formatting second table takes 153.8594319820404 seconds ---
# Josh Rogers
# https://www.fangraphs.com/players/josh-rogers/18510/ table_advanced is None
# --- scraping tables takes 159.039568901062 seconds ---
# --- formatting first table takes 159.039568901062 seconds ---
# --- formatting second table takes 159.039568901062 seconds ---
# --- 160.96342086791992 seconds ---
# --- getting url takes 11.57971739768982 seconds ---
# Luis García
# --- formatting second table takes 12.443406581878662 seconds ---
# Josh Bell
# --- formatting second table takes 13.27125859260559 seconds ---
# Juan Soto
# --- formatting second table takes 14.069122552871704 seconds ---
# Nelson Cruz
# --- formatting second table takes 15.093381643295288 seconds ---
# Yadiel Hernandez
# --- formatting second table takes 16.354007959365845 seconds ---
# César Hernández
# --- formatting second table takes 17.604660511016846 seconds ---
# Keibert Ruiz
# --- formatting second table takes 19.048799514770508 seconds ---
# Maikel Franco
# --- formatting second table takes 21.412471771240234 seconds ---
# Lane Thomas
# --- formatting second table takes 23.188746690750122 seconds ---
# Tres Barrera
# --- formatting second table takes 24.426405429840088 seconds ---
# Alcides Escobar
# --- formatting second table takes 25.782777547836304 seconds ---
# Ehire Adrianza
# --- formatting second table takes 27.125183582305908 seconds ---
# Victor Robles
# --- formatting second table takes 28.56632661819458 seconds ---
# Josiah Gray
# --- formatting second table takes 31.128469705581665 seconds ---
# Erick Fedde
# --- formatting second table takes 32.685303688049316 seconds ---
# Patrick Corbin
# --- formatting second table takes 34.057631969451904 seconds ---
# Paolo Espino
# --- formatting second table takes 35.65368962287903 seconds ---
# Kyle Finnegan
# --- formatting second table takes 36.91331672668457 seconds ---
# Carl Edwards Jr.
# --- formatting second table takes 38.339500188827515 seconds ---
# Steve Cishek
# --- formatting second table takes 40.11375284194946 seconds ---
# Andres Machado
# --- formatting second table takes 41.566863775253296 seconds ---
# Mason Thompson
# --- formatting second table takes 42.682876110076904 seconds ---
# Jordan Weems
# --- formatting second table takes 44.47807216644287 seconds ---
# Hunter Harvey
# --- formatting second table takes 46.31219220161438 seconds ---
# Tyler Clippard
# --- formatting second table takes 47.56082344055176 seconds ---
# Erasmo Ramírez
# --- formatting second table takes 49.45178985595703 seconds ---
# Cory Abbott
# --- formatting second table takes 50.892905712127686 seconds ---
# Carter Kieboom
# --- formatting second table takes 52.290194272994995 seconds ---
# Seth Romero
# --- formatting second table takes 53.654515504837036 seconds ---
# Joe Ross
# --- formatting second table takes 54.819398641586304 seconds ---
# Aníbal Sánchez
# --- formatting second table takes 55.937406063079834 seconds ---
# Stephen Strasburg
# --- formatting second table takes 57.4134578704834 seconds ---
# Jackson Tetreault
# --- formatting second table takes 58.63718342781067 seconds ---
# Víctor Arano
# --- formatting second table takes 60.81937003135681 seconds ---
# Sean Doolittle
# --- formatting second table takes 62.13282871246338 seconds ---
# Reed Garrett
# --- formatting second table takes 63.546046018600464 seconds ---
# Will Harris
# --- formatting second table takes 64.6889865398407 seconds ---
# Evan Lee
# --- formatting second table takes 66.03039836883545 seconds ---
# Tanner Rainey
# --- formatting second table takes 67.26808619499207 seconds ---
# Josh Rogers
# --- formatting second table takes 68.84686136245728 seconds ---
# --- 71.31826853752136 seconds ---

# %%
# Out:
# T:\Baseball\export

# %%
all_teams = ['orioles','red sox','white sox', 'guardians', 'tigers', 'astros', 'royals', 'angels', 'twins', 'yankees',
            'athletics', 'mariners' , 'rays', 'rangers', 'blue jays', 'diamondbacks', 'braves','cubs','reds',
             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
             'nationals']

# %%
# Player test pitcher 

geckodriver = "C:\Program Files (x86)\geckodriver"
os.environ["webdriver.gecko.driver"] = geckodriver

driver = webdriver.Firefox(executable_path = geckodriver)

#https://www.fangraphs.com/players/daniel-castano/19805/

df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'K/9', 'BB/9', 'K/BB','HR/9','K%','BB%','K-BB%','AVG',
                           'WHIP','BABIP','LOB%','FIP','xFIP'])

table_advanced_dc, table_battedball_dc = pitching('https://www.fangraphs.com/players/daniel-castano/19805/', season, driver)

df_advanced_dc = advanced_pitcher_table(table_advanced_dc, 'advanced', ['Handedness'], df_advanced, 'team', 'DC', bat_pitch = 'Pitcher')

# %%
table_advanced_dc
# Out:
# <div class="player-page-table" id="advanced"><div class="player-page-table__header"><a href="#Advanced" id="Advanced"><h2>Advanced</h2></a></div><div><div class="fg-data-grid undefined sort-disabled"><div class="table-wrapper-outer"><div class="table-wrapper-inner"><div class="table-scroll"><table><tbody><tr class=""><th class="align-left fixed undefined" data-col="0" data-stat="Season">Season</th><th class="align-left fixed undefined" data-col="1" data-stat="Split">Handedness</th><th class="align-right undefined" data-col="2" data-stat="K/9">K/9</th><th class="align-right undefined" data-col="3" data-stat="BB/9">BB/9</th><th class="align-right undefined" data-col="4" data-stat="K/BB">K/BB</th><th class="align-right undefined" data-col="5" data-stat="HR/9">HR/9</th><th class="align-right undefined" data-col="6" data-stat="K%">K%</th><th class="align-right undefined" data-col="7" data-stat="BB%">BB%</th><th class="align-right undefined" data-col="8" data-stat="K-BB%">K-BB%</th><th class="align-right undefined" data-col="9" data-stat="AVG">AVG</th><th class="align-right undefined" data-col="10" data-stat="WHIP">WHIP</th><th class="align-right undefined" data-col="11" data-stat="BABIP">BABIP</th><th class="align-right undefined" data-col="12" data-stat="LOB%">LOB%</th><th class="align-right undefined" data-col="13" data-stat="FIP">FIP</th><th class="align-right undefined" data-col="14" data-stat="xFIP">xFIP</th></tr><tr class="row-mlb-season"><td class="align-left fixed" data-stat="Season">2022</td><td class="align-left fixed" data-stat="Split">vs L</td><td class="align-right" data-stat="K/9">13.50</td><td class="align-right" data-stat="BB/9">0.00</td><td class="align-right" data-stat="K/BB">2.00</td><td class="align-right" data-stat="HR/9">0.00</td><td class="align-right" data-stat="K%">40.0%</td><td class="align-right" data-stat="BB%">0.0%</td><td class="align-right" data-stat="K-BB%">40.0%</td><td class="align-right" data-stat="AVG">.200</td><td class="align-right" data-stat="WHIP">0.75</td><td class="align-right" data-stat="BABIP">.333</td><td class="align-right" data-stat="LOB%">100.0%</td><td class="align-right" data-stat="FIP">0.14</td><td class="align-right" data-stat="xFIP">2.32</td></tr><tr class="row-mlb-season"><td class="align-left fixed" data-stat="Season">2022</td><td class="align-left fixed" data-stat="Split">vs R</td><td class="align-right" data-stat="K/9">0.00</td><td class="align-right" data-stat="BB/9">0.00</td><td class="align-right" data-stat="K/BB">0.00</td><td class="align-right" data-stat="HR/9">0.00</td><td class="align-right" data-stat="K%">0.0%</td><td class="align-right" data-stat="BB%">0.0%</td><td class="align-right" data-stat="K-BB%">0.0%</td><td class="align-right" data-stat="AVG">.364</td><td class="align-right" data-stat="WHIP">1.50</td><td class="align-right" data-stat="BABIP">.333</td><td class="align-right" data-stat="LOB%">75.0%</td><td class="align-right" data-stat="FIP">3.14</td><td class="align-right" data-stat="xFIP">3.68</td></tr><tr class="row-mlb-season"><th class="align-left fixed undefined" data-col="0" data-stat="Season">Season</th><th class="align-left fixed undefined" data-col="1" data-stat="Split">Home / Away</th><th class="align-right undefined" data-col="2" data-stat="K/9">K/9</th><th class="align-right undefined" data-col="3" data-stat="BB/9">BB/9</th><th class="align-right undefined" data-col="4" data-stat="K/BB">K/BB</th><th class="align-right undefined" data-col="5" data-stat="HR/9">HR/9</th><th class="align-right undefined" data-col="6" data-stat="K%">K%</th><th class="align-right undefined" data-col="7" data-stat="BB%">BB%</th><th class="align-right undefined" data-col="8" data-stat="K-BB%">K-BB%</th><th class="align-right undefined" data-col="9" data-stat="AVG">AVG</th><th class="align-right undefined" data-col="10" data-stat="WHIP">WHIP</th><th class="align-right undefined" data-col="11" data-stat="BABIP">BABIP</th><th class="align-right undefined" data-col="12" data-s ...

# %%
#map table

teams = ['orioles','red sox','white sox', 'guardians', 'tigers', 'astros', 'royals', 'angels', 'twins', 'yankees',
            'athletics', 'mariners' , 'rays', 'rangers', 'blue jays', 'diamondbacks', 'braves','cubs','reds',
             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
             'nationals']

teams_abbr = ['BAL', 'BOS' , 'CHW', 'CLE', 'DET' , 'HOU', 'KCR', 'LAA', 'MIN', 'NYY', 'OAK', 'SEA', 'TBR', 'TEX', 'TOR',
             'ARI','ATL','CHC','CIN','COL','LAD','MIA','MIL','NYM','PHI','PIT','SDP','SFG','STL','WSN']

teams_mapping = pd.DataFrame({'Teams': teams, 'Teams_abbr': teams_abbr})
teams_mapping.to_csv("teams_mapping.csv",  index = False)

# %%
df_team_abbr = pd.read_csv("teams_mapping.csv")

# %%
df_team_abbr[df_team_abbr['Teams'] == 'orioles']['Teams_abbr'].to_string()[5:]
# Out:
# 'BAL'

# %% [markdown]
# ## Check missing players of each team, then append to current file

# %%
def load_team_mapping():
    os.chdir('T:\Baseball')
    df = pd.read_csv('teams_mapping.csv', index_col=False)
    return df

def get_all_players(teams):
    geckodriver = "C:\Program Files (x86)\geckodriver"
    os.environ["webdriver.gecko.driver"] = geckodriver
    
    driver = webdriver.Firefox(executable_path = geckodriver)

    # Get all players
    player_all = []
    player_url_all = []
    team_all = []
    team_abbr = []
    df_team_abbr = load_team_mapping()
    for team in teams:
        team_abbr_tmp = df_team_abbr[df_team_abbr['Teams'] == team]['Teams_abbr'].to_string()[5:]
        roster_url = get_roster_url(team)
        roster_table = get_roster_source(roster_url, driver)
    
        player, player_url = get_player_url(roster_table)
        for p in player:
            player_all.append(p)
            team_all.append(team)
            team_abbr.append(team_abbr_tmp)
        for u in player_url:
            player_url_all.append(u)
            
    df_player_all = pd.DataFrame({'Player':player_all, 'Player_url': player_url_all, 'Team':team_all, 'Team_abbr': team_abbr})       
    return df_player_all

#Append function

# Loop over pitcher advanced file
def find_missing_pitchers(directory, df_player_all, stat_cat, stat, season):
    
    geckodriver = "C:\Program Files (x86)\geckodriver"
    os.environ["webdriver.gecko.driver"] = geckodriver

    driver = webdriver.Firefox(executable_path = geckodriver)

    df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'K/9', 'BB/9', 'K/BB','HR/9','K%','BB%','K-BB%','AVG',
                           'WHIP','BABIP','LOB%','FIP','xFIP'])
    df_battedball = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes'])   
    os.chdir(directory)
    for filename in os.listdir(directory):

        if 'csv' not in filename:
            continue
        f = os.path.join(directory, filename)
        df_read = pd.read_csv(f)
        orig_file_size = len(df_read)
        #team_to_check = df_read['Team'][0]
        players_to_check = df_read['Player'].tolist()
        team_to_check = filename[:filename.index('_2022')]
        
        team_name_formal = df_read['Team'][0]
        all_active_players_of_team = df_player_all[df_player_all['Team'] == team_to_check]['Player'].tolist()
              
        for i in range(len(all_active_players_of_team)):  
            if all_active_players_of_team[i] not in players_to_check: # if current online roster player not in local
                print(team_to_check, all_active_players_of_team[i])
                table_advanced, table_battedball = pitching(df_player_all['Player_url'][i], season, driver)
    
                if stat_cat == 'advanced':
                    df_advanced_player = advanced_pitcher_table(table_advanced, stat_cat, stat, df_advanced, team = team_name_formal, player = all_active_players_of_team[i], bat_pitch = 'Pitcher')
                    df_read = df_read.append(df_advanced_player)
            
                if stat_cat == 'batted-ball':
                    df_battedball_player = battedball_table(table_battedball, stat_cat, stat, df_battedball, team = team_name_formal, player = all_active_players_of_team[i], bat_pitch = 'Pitcher')
                    df_read = df_read.append(df_battedball_player)
                    
        if (stat_cat == 'advanced') and (len(df_read) != orig_file_size):
            print(len(df_read) - orig_file_size)
            df_read.to_csv(team_to_check + '_' + str(season) + "_pitch_advanced.csv" ,index = False)
            print('export done')
        if (stat_cat == 'batted-ball') and (len(df_read) != orig_file_size):    
            print(len(df_read) - orig_file_size)
            df_read.to_csv(team_to_check + '_' + str(season) + "_pitch_battedball.csv",index = False)
            print('export done')
    driver.quit()



def find_missing_batters(directory, df_player_all, stat_cat, stat, season):
    
    geckodriver = "C:\Program Files (x86)\geckodriver"
    os.environ["webdriver.gecko.driver"] = geckodriver

    driver = webdriver.Firefox(executable_path = geckodriver)

    df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat', 'Bat/Pitch','Stat', 'Season', 
                           'Split', 'BB%', 'K%', 'BB/K' ,'AVG', 'OBP', 
                           'SLG', 'OPS', 'ISO', 'BABIP', 'wRC', 'wRAA', 'wOBA', 'wRC+'])
    df_battedball = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes'])  
    os.chdir(directory)
    for filename in os.listdir(directory):
        if 'csv' not in filename:
            continue
        f = os.path.join(directory, filename)
        df_read = pd.read_csv(f)
        orig_file_size = len(df_read)
        #team_to_check = df_read['Team'][0]
        players_to_check = df_read['Player'].tolist()
        team_to_check = filename[:filename.index('_2022')]
        team_name_formal = df_read['Team'][0]
        all_active_players_of_team = df_player_all[df_player_all['Team'] == team_to_check]['Player'].tolist()

        for i in range(len(all_active_players_of_team)):
            if all_active_players_of_team[i] not in players_to_check:
                print(team_to_check, all_active_players_of_team[i])
                table_advanced, table_battedball = batting(df_player_all['Player_url'][i], season, driver)
                #print(table_advanced)

                if stat_cat == 'advanced':
                    df_advanced_player = advanced_batter_table(table_advanced, stat_cat, stat, df_advanced, team = team_name_formal, player = all_active_players_of_team[i], bat_pitch = 'Batter')
                    #print(df_advanced_player)
                    df_read = df_read.append(df_advanced_player)
            
                if stat_cat == 'batted-ball':
                    df_battedball_player = battedball_table(table_battedball, stat_cat, stat, df_battedball, team = team_name_formal, player = all_active_players_of_team[i], bat_pitch = 'Batter')
                    #print(df_battedball_player)
                    df_read = df_read.append(df_battedball_player)
        if (stat_cat == 'advanced') and (len(df_read) != orig_file_size):
            print(len(df_read) - orig_file_size)
            
            df_read.to_csv(team_to_check + '_' + str(season) + "_bat_advanced.csv" ,index = False)
            print('export done')
        if (stat_cat == 'batted-ball') and (len(df_read) != orig_file_size):    
            print(len(df_read) - orig_file_size)
            df_read.to_csv(team_to_check + '_' + str(season) + "_bat_battedball.csv",index = False)
            print('export done')
    driver.quit()

# %% [markdown]
# # Handedness Report

# %%
def get_player_url_handedness(roster_table):
    player = []
    player_url = []
    player_pos = []
    player_hand = []
    
    dcrt = roster_table.find_all('div',{"class":"depth-charts__roster-tables"})
    
    # first seven tables are the 40 man roster
    for i in range(7):        
        for row2 in dcrt[i].tbody.find_all('td',{"data-stat":"PLAYER"}):
                    
            #player list
            player_tmp = row2.text
            player.append(player_tmp)
                    
            #player url list
            player_url_tmp = row2.find('a')['href']
            size = len(player_url_tmp)
            player_url_tmp = 'https:' + player_url_tmp[:size - 5]
            player_url.append(player_url_tmp)
    for i in range(7): 
        for row3 in dcrt[i].tbody.find_all('td',{"data-stat":"POS"}):
            player_pos_tmp = row3.text
            player_pos.append(player_pos_tmp)
    for i in range(7): 
        for row4 in dcrt[i].tbody.find_all('tr'):
            if row4.find('td',{"data-stat":"THR"}) is not None:
                player_hand_tmp = row4.find('td',{"data-stat":"THR"}).text
            else:
                player_hand_tmp = row4.find('td',{"data-stat":"BATS"}).text
            player_hand.append(player_hand_tmp)
            
    rightLen = len(player)
    player_pos =  player_pos[:rightLen]
    player_hand = player_hand[:rightLen]

    return player, player_url, player_pos, player_hand

def get_all_players_handedness(teams):
    geckodriver = "C:\Program Files (x86)\geckodriver"
    os.environ["webdriver.gecko.driver"] = geckodriver
    
    driver = webdriver.Firefox(executable_path = geckodriver)

    # Get all players
    player_all = []
    player_url_all = []
    player_pos_all = []
    player_hand_all = []
    team_all = []
    team_abbr = []
    df_team_abbr = load_team_mapping()
    for team in teams:
        team_abbr_tmp = df_team_abbr[df_team_abbr['Teams'] == team]['Teams_abbr'].to_string()[5:]
        roster_url = get_roster_url(team)
        roster_table = get_roster_source(roster_url, driver)
    
        player, player_url, player_pos, player_hand = get_player_url_handedness(roster_table)
        for p in player:
            player_all.append(p)
            team_all.append(team)
            team_abbr.append(team_abbr_tmp)
        for u in player_url:
            player_url_all.append(u)
            
        for pos in player_pos:
            player_pos_all.append(pos)
        for hand in player_hand:
            player_hand_all.append(hand)
    
    print(len(player_all))
    print(player_all)
    print(len(player_url_all))
    print(len(team_all))
    print(len(team_abbr))
    print(len(player_pos_all))
    print(len(player_hand_all))    
    print(player_pos_all)
    print(player_hand_all)  
    df_player_all = pd.DataFrame({'Player':player_all, 'Player_url': player_url_all, 'Team':team_all, 'Team_abbr': team_abbr,
                                 'Player_pos':player_pos_all, 'Player_hand':player_hand_all})       
    return df_player_all

# %%
teams =  ['orioles','red sox','white sox', 'guardians', 'tigers', 'astros', 'royals', 'angels', 'twins', 'yankees',
            'athletics', 'mariners' , 'rays', 'rangers', 'blue jays', 'diamondbacks', 'braves','cubs','reds',
             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
             'nationals']
handPosition = get_all_players_handedness(teams)
# Out:
# 1040
# ['Cedric Mullins', 'Trey Mancini', 'Anthony Santander', 'Ryan Mountcastle', 'Austin Hays', 'Adley Rutschman', 'Ramón Urías', 'Rougned Odor', 'Jorge Mateo', 'Robinson Chirinos', 'Jonathan Araúz', 'Tyler Nevin', 'Ryan McKenna', 'Jordan Lyles', 'Spenser Watkins', 'Tyler Wells', 'Dean Kremer', 'Austin Voth', 'Jorge López', 'Félix Bautista', 'Dillon Tate', 'Cionel Pérez', 'Joey Krehbiel', 'Keegan Akin', 'Bryan Baker', 'Rico Garcia', 'Kyle Bradish', 'Chris Ellis', 'John Means', 'Louis Head', 'Travis Lakins Sr.', 'Alexander Wells', 'Jarren Duran', 'Rafael Devers', 'J.D. Martinez', 'Xander Bogaerts', 'Alex Verdugo', 'Trevor Story', 'Franchy Cordero', 'Christian Vázquez', 'Jackie Bradley Jr.', 'Kevin Plawecki', 'Bobby Dalbec', 'Jeter Downs', 'Rob Refsnyder', 'Nick Pivetta', 'Chris Sale', 'Kutter Crawford', 'Tanner Houck', 'John Schreiber', 'Matt Strahm', 'Jake Diekman', 'Austin Davis', 'Hirokazu Sawamura', 'Ryan Brasier', 'K
 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'R', 'R', 'L', 'L', 'R', 'L', 'R', 'R', 'L', 'R', 'R', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'S', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'R', 'L', 'R', 'S', 'R', 'L', ...

# %%
handPosition.to_csv('T:\Baseball\handednessReport.csv',index = False)

# %% [markdown]
# # Convert accented characters

# %%
def replace_accents(pitch_or_bat):
    directory = 'T:\Baseball\\export\\6_15_export\\2022_' + pitch_or_bat
    os.chdir(directory)
    for filename in os.listdir(directory):
        if 'csv' not in filename:
            continue
        team_to_check = filename[:filename.index('2022')]
        f = os.path.join(directory, filename)
        df_read = pd.read_csv(f)
        for i in range(len(df_read)):
            df_read['Player'][i] = unidecode.unidecode(df_read['Player'][i])
        df_read.to_csv(team_to_check + "2022 " + pitch_or_bat + ".csv" , index = False)
        print('done')

# %%
replace_accents('pitch_battedball')
# Out:
# C:\Users\tengf\AppData\Local\Temp/ipykernel_13604/2405763659.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_read['Player'][i] = unidecode.unidecode(df_read['Player'][i])
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done

# %%
teams =  ['orioles','red sox','white sox', 'guardians', 'tigers', 'astros', 'royals', 'angels', 'twins', 'yankees',
            'athletics', 'mariners' , 'rays', 'rangers', 'blue jays', 'diamondbacks', 'braves','cubs','reds',
             'rockies','dodgers', 'marlins', 'brewers', 'mets', 'phillies', 'pirates', 'padres', 'giants', 'cardinals', 
             'nationals']

#teams =  ['yankees']

df_player_all = get_all_players(teams)

# %%
#df_player_all[df_player_all['Team'] == 'yankees'] 
df_player_all
# Out:
#                  Player                                         Player_url  \
# 0        Cedric Mullins  https://www.fangraphs.com/players/cedric-mulli...
# 1          Trey Mancini  https://www.fangraphs.com/players/trey-mancini...
# 2     Anthony Santander  https://www.fangraphs.com/players/anthony-sant...
# 3      Ryan Mountcastle  https://www.fangraphs.com/players/ryan-mountca...
# 4           Austin Hays  https://www.fangraphs.com/players/austin-hays/...
# ...                 ...                                                ...
# 1032       Reed Garrett  https://www.fangraphs.com/players/reed-garrett...
# 1033        Will Harris  https://www.fangraphs.com/players/will-harris/...
# 1034           Evan Lee  https://www.fangraphs.com/players/evan-lee/24988/
# 1035      Tanner Rainey  https://www.fangraphs.com/players/tanner-raine...
# 1036        Josh Rogers  https://www.fangraphs.com/players/josh-rogers/...
#
#            Team Team_abbr
# 0       orioles       BAL
# 1       orioles       BAL
# 2       orioles       BAL
# 3       orioles       BAL
# 4       orioles       BAL
# ...         ...       ...
# 1032  nationals       WSN
# 1033  nationals       WSN
# 1034  nationals       WSN
# 1035  nationals       WSN
# 1036  nationals       WSN
#
# [1037 rows x 4 columns]

# %%
# Find missing pitchers

directory = 'T:\Baseball\\export\\7_13_export\\2022_pitch_battedball'
stat = ['Handedness']
find_missing_pitchers(directory, df_player_all, 'batted-ball', stat, '2022')
# Out:
# angels Michael Stefanic
# angels Mike Trout
# angels Taylor Ward
# angels Jared Walsh
# angels Luis Rengifo
# angels Max Stassi
# angels Jonathan Villar
# angels Brandon Marsh
# angels Kurt Suzuki
# brewers Aaron Ashby
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# brewers Josh Hader
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# brewers Devin Williams
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# brewers Brad Boxberger
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# brewers Trevor Gott
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# brewers Brent Suter
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# brewers Hoby Milner
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# brewers Connor Sadzeck
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# brewers Jandel Gustave
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# brewers Adrian Houser
# https://www.fangraphs.com/players/john-means/16269/ table_advanced is None
# brewers Freddy Peralta
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# brewers Jake Cousins
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# brewers Luis Perdomo
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# brewers Miguel Sánchez
# brewers Justin Topa
# 8
# export done
# cardinals Adam Wainwright
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# cardinals Andre Pallante
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# cardinals Miles Mikolas
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# cardinals Ryan Helsley
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# cardinals Giovanny Gallegos
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# cardinals Génesis Cabrera
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# cardinals Jordan Hicks
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# cardinals Junior Fernández
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# cardinals Johan Oviedo
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# cardinals Zack Thompson
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# cardinals T.J. McFarland
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# cardinals Packy Naughton
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# cardinals Drew VerHagen
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# cardinals Jack Flaherty
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# cardinals Dakota Hudson
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# cardinals Steven Matz
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# cardinals Alex Reyes
# 4
# export done
# cubs Marcus Stroman
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# cubs Drew Smyly
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# cubs Adrian Sampson
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# dodgers Julio Urías
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# dodgers Mitch White
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# dodgers Tony Gonsolin
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# dodgers Tyler Anderson
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# dodgers Craig Kimbrel
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# dodgers Evan Phillips
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# dodgers Alex Vesia
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# dodgers Yency Almonte
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# dodgers Phil Bickford
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# dodgers Caleb Ferguson
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# dodgers Reyes Moronta
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# dodgers David Price
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# dodgers Walker Buehler
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# dodgers Andrew Heaney
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# dodgers Dustin May
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# dodgers Danny Duffy
# dodgers Victor González
# dodgers Brusdar Graterol
# dodgers Daniel Hudson
# dodgers Tommy Kahnle
# dodgers Jimmy Nelson
# dodgers Blake Treinen
# 28
# export done
# giants Logan Webb
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# giants Carlos Rodón
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# giants Alex Wood
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# giants Alex Cobb
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# giants Camilo Doval
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# giants Dominic Leone
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# giants Tyler Rogers
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# giants John Brebbia
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# giants Jarlín García
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# giants Mauricio Llovera
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# giants Yunior Marte
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# giants Sam Long
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# giants Colton Welker
# https://www.fangraphs.com/players/john-means/16269/ table_advanced is None
# giants Matthew Boyd
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# giants Anthony DeSclafani
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# rangers Glenn Otto
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# rangers Brett Martin
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# rangers Matt Moore
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# rangers Matt Bush
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# rangers Brock Burke
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# rangers Dennis Santana
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# rangers José Leclerc
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# rangers Garrett Richards
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# rangers A.J. Alexy
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# rangers Dane Dunning
# https://www.fangraphs.com/players/john-means/16269/ table_advanced is None
# rangers Joe Barlow
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# rangers Jonathan Hernández
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# 4
# export done
# rays Shane McClanahan
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# rays Drew Rasmussen
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# rays Luis Patiño
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# rays Corey Kluber
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# rays Colin Poche
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# rays Jason Adam
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# rays Brooks Raley
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# rays Matt Wisler
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# rays Jalen Beeks
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# rays Ryan Thompson
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# rays Shawn Armstrong
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# rays Luke Bard
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# rays Ralph Garza Jr.
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# rays Shane Baz
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# rays Yonny Chirinos
# rays Josh Fleming
# rays Tyler Glasnow
# rays Brendan McKay
# rays Jeffrey Springs
# rays Nick Anderson
# rays JT Chargois
# rays Pete Fairbanks
# rays J.P. Feyereisen
# rays Andrew Kittredge
# 40
# export done
# red sox Nathan Eovaldi
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# red sox Nick Pivetta
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# red sox Chris Sale
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# red sox Kutter Crawford
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# red sox Tanner Houck
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# red sox John Schreiber
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# red sox Garrett Whitlock
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# red sox Jake Diekman
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# red sox Austin Davis
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# red sox Hirokazu Sawamura
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# red sox Kaleb Ort
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# red sox Darwinzon Hernandez
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# red sox Ryan Brasier
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# red sox Rich Hill
# https://www.fangraphs.com/players/john-means/16269/ table_advanced is None
# red sox James Paxton
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# red sox Connor Seabold
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# red sox Michael Wacha
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# red sox Josh Winckowski
# red sox Matt Barnes
# red sox Tyler Danish
# red sox Matt Strahm
# red sox Josh Taylor
# 20
# export done
# reds Max Schrock
# reds Luis Castillo
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# reds Hunter Greene
# https://www.fangraphs.com/players/spenser-watkins/17489/ table_advanced is None
# reds Nick Lodolo
# https://www.fangraphs.com/players/tyler-wells/20000/ table_advanced is None
# reds Graham Ashcraft
# https://www.fangraphs.com/players/dean-kremer/19350/ table_advanced is None
# reds Mike Minor
# https://www.fangraphs.com/players/austin-voth/15047/ table_advanced is None
# reds Alexis Díaz
# https://www.fangraphs.com/players/jorge-lopez/14527/ table_advanced is None
# reds Hunter Strickland
# https://www.fangraphs.com/players/felix-bautista/20666/ table_advanced is None
# reds Jeff Hoffman
# https://www.fangraphs.com/players/dillon-tate/17796/ table_advanced is None
# reds Reiver Sanmartin
# https://www.fangraphs.com/players/cionel-perez/19614/ table_advanced is None
# reds Ian Gibaut
# https://www.fangraphs.com/players/joey-krehbiel/13707/ table_advanced is None
# reds Joel Kuhnel
# https://www.fangraphs.com/players/keegan-akin/19362/ table_advanced is None
# reds Dauri Moreta
# https://www.fangraphs.com/players/bryan-baker/19804/ table_advanced is None
# reds Buck Farmer
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# reds Justin Dunn
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# reds Vladimir Gutierrez
# reds Tyler Mahle
# reds Connor Overton
# reds Tejay Antone
# reds Luis Cessa
# reds Ross Detwiler
# reds Daniel Duarte
# reds Tony Santillan
# reds Lucas Sims
# reds Art Warren
# reds Justin Wilson
# 48
# export done
# rockies Kris Bryant
# rockies Germán Márquez
# https://www.fangraphs.com/players/jordan-lyles/7593/ table_advanced is None
# rockies José Ureña
# yankees Ryan Weber
# https://www.fangraphs.com/players/rico-garcia/20023/ table_advanced is None
# yankees Ben Rortvedt
# https://www.fangraphs.com/players/kyle-bradish/24586/ table_advanced is None
# yankees Domingo Germán
# https://www.fangraphs.com/players/chris-ellis/16125/ table_advanced is None
# yankees Luis Severino
# https://www.fangraphs.com/players/john-means/16269/ table_advanced is None
# yankees Zack Britton
# https://www.fangraphs.com/players/louis-head/13259/ table_advanced is None
# yankees Chad Green
# https://www.fangraphs.com/players/travis-lakins-sr/18600/ table_advanced is None
# yankees Ron Marinaccio
# https://www.fangraphs.com/players/alexander-wells/19845/ table_advanced is None
# yankees Stephen Ridings
# 4
# export done

# %%
df_player_all.to_csv('all_active_players6_16.csv')

# %% [markdown]
# 1. Similar character latin characters lookup
# 2. FP scrape
# 3. Correlation
# 4. Pick top stats (ensure signs)
# 5. 2021 data
# 6. game time match players
# 7. format cleanup
# 8. auto generate metrics
# 9. auto generate missing players

# %%
driver = webdriver.Firefox(executable_path = geckodriver)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13604/1212236999.py in <module>
# ----> 1 driver = webdriver.Firefox(executable_path = geckodriver)
#       2 batting(df_player_all[df_player_all['Player'] == 'J.J. Matijevic']['Player_url'], season, driver)
#
# NameError: name 'geckodriver' is not defined

# %%
table_advanced, table_battedball = batting('https://www.fangraphs.com/players/jj-matijevic/20165/', '2022', driver)

# %%
df_advanced = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'K/9', 'BB/9', 'K/BB','HR/9','K%','BB%','K-BB%','AVG',
                           'WHIP','BABIP','LOB%','FIP','xFIP'])
df_battedball = pd.DataFrame(columns=['Team', 'Player','Stat_cat','Bat/Pitch','Stat', 'Season', 
                           'Split', 'GB/FB','LD%','GB%','FB%','IFFB%','HR/FB','IFH%','BUH%',
                           'Pull%','Cent%','Oppo%','Soft%','Med%','Hard%','Pitches','Balls','Strikes']) 

df_advanced_player = advanced_batter_table(table_advanced, 'advanced', stat, df_advanced, team = 'Astros', player = 'J.J. Matijevic', bat_pitch = 'Batter')

# %%
df_advanced_player
# Out:
#      Team          Player  Stat_cat Bat/Pitch        Stat Season      Split  \
# 0  Astros  J.J. Matijevic  advanced    Batter  Handedness   2022  vs L as L
# 1  Astros  J.J. Matijevic  advanced    Batter  Handedness   2022  vs R as L
# 2  Astros  J.J. Matijevic  advanced    Batter  Handedness   2022       vs L
# 3  Astros  J.J. Matijevic  advanced    Batter  Handedness   2022       vs R
#
#    K/9 BB/9 K/BB  ... xFIP  BB/K   ISO   OBP   OPS   SLG  wOBA  wRAA wRC  wRC+
# 0  NaN  NaN  NaN  ...  NaN  0.00  .000  .000  .000  .000  .000  -0.2   0  -100
# 1  NaN  NaN  NaN  ...  NaN  0.00  .000  .000  .000  .000  .000  -1.2  -1  -100
# 2  NaN  NaN  NaN  ...  NaN  0.00  .000  .000  .000  .000  .000  -0.2   0  -100
# 3  NaN  NaN  NaN  ...  NaN  0.00  .000  .000  .000  .000  .000  -1.2  -1  -100
#
# [4 rows x 29 columns]
